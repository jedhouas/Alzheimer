# %% [markdown]
# <a href="https://colab.research.google.com/github/jedhouas/Alzheimer/blob/master/final_speech_commands_mva_2020_py3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Speech Commands
# In this Practical work you will be given voice commands recorded by devices such as Amazon Alexa or Google Echo assistants. The task is to recognize the voice command from the audio signal. The dataset is stored as waveforms, each one being a 1 second file containing one voice command.
#
# ## I. Classification of segmented voice commands
#
# The first step will be to extract speech features, either Melfilterbanks or MFCC. Then you will train different type of classifiers to recognize the spoken voice command from the speech features. These classifiers are a Logistic Regression and a Neural Network. You can change the **Runtime of your colab instance and use a GPU** if you are using Neural Networks.
#
# ### The next block downloads the dataset and extracts it to your Colab instance. RUN ONLY ONCE!

# %%
# !wget http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz
# !rm -rf speech_commands
# !mkdir speech_commands
# !tar -zxf speech_commands_v0.01.tar.gz -C speech_commands
# Out:
# --2020-02-12 17:27:51--  http://download.tensorflow.org/data/speech_commands_v0.01.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.111.128, 2607:f8b0:4001:c07::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.111.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1489096277 (1.4G) [application/gzip]
# Saving to: ‘speech_commands_v0.01.tar.gz’
#
# speech_commands_v0. 100%[===================>]   1.39G   105MB/s    in 15s
#
# 2020-02-12 17:28:06 (96.0 MB/s) - ‘speech_commands_v0.01.tar.gz’ saved [1489096277/1489096277]

# %% [markdown]
# ### This block installs necessary libraries

# %%
import numpy as np
# !pip install git+https://github.com/bootphon/spectral.git
# !pip install jiwer
import jiwer
import spectral
import librosa
import IPython
import os, glob
import ast
import scipy.io.wavfile as wav
import sklearn
from sklearn.neural_network import MLPClassifier
import time
from tqdm import tqdm
import random
import matplotlib.pyplot as plt
# %matplotlib inline
random.seed(777)
# Out:
# Collecting git+https://github.com/bootphon/spectral.git
#   Cloning https://github.com/bootphon/spectral.git to /tmp/pip-req-build-lcacaui3
#   Running command git clone -q https://github.com/bootphon/spectral.git /tmp/pip-req-build-lcacaui3
# Requirement already satisfied (use --upgrade to upgrade): spectral==0.1.7 from git+https://github.com/bootphon/spectral.git in /usr/local/lib/python3.6/dist-packages
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.6/dist-packages (from spectral==0.1.7) (1.17.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from spectral==0.1.7) (1.4.1)
# Building wheels for collected packages: spectral
#   Building wheel for spectral (setup.py) ... done
#   Created wheel for spectral: filename=spectral-0.1.7-cp36-cp36m-linux_x86_64.whl size=63198 sha256=e2cab4abd4d1f836232c126879694f7a148d968502ea555659831f3c4fae4bff
#   Stored in directory: /tmp/pip-ephem-wheel-cache-58werwgh/wheels/73/fd/30/6edc3e8687a96ba559a35ad0de5fa98922066731d716e4c22d
# Successfully built spectral
# Requirement already satisfied: jiwer in /usr/local/lib/python3.6/dist-packages (1.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from jiwer) (1.17.5)

# %% [markdown]
# These functions are just utilities that will help facilitate features extraction. Feel free to modify them if you need to, but it is not required.

# %%
def txt2list(filename):
    lines_list = []
    with open(filename, 'r') as txt:
        for line in txt:
            lines_list.append(line.rstrip('\n'))
    return lines_list

def transform_wavs(wavs_list, feature_func):
    features = []
    for wav in wavs_list:
        features.append(feature_func.transform(wav).flatten())
    return features

def pad(features, max_len=1616):
    padded_features =[]
    for feat_file in features:
        max_len = max(max_len, feat_file.shape[0])
    for feat_file in features:
        pad_size = max_len - feat_file.shape[0]
        left_pad = pad_size // 2
        right_pad = pad_size - left_pad
        padded_features.append(np.pad(feat_file, ((left_pad, right_pad),), 'constant', constant_values=(0, 0)))
    return padded_features

# %% [markdown]
# Load the data. In this practical work, you are expected to train your models on the training set and evaluate them on the validation set. When you will get your final best model, report the results on the test set.

# %%
## Loading data
# label_set = ['no', 'yes', 'up', 'right', 'down', 'left', 'one', 'on', 'off', 'stop', 'go']

path_to_wav = '/content/speech_commands/'
directories_speech_commands = os.listdir(path_to_wav)
directories_speech_commands = [x for x in directories_speech_commands if os.path.isdir(os.path.join(path_to_wav,x))]
directories_speech_commands = [x for x in directories_speech_commands if x != '_background_noise_']
directories_speech_commands
label_set = directories_speech_commands
nb_ex_per_class = 300 # To have balance classes for the NN/Logistic Regression
# Valid set
valid_list = txt2list('/content/speech_commands/validation_list.txt')
# Test set
test_list = txt2list('/content/speech_commands/testing_list.txt')

# %%
# Iterate over files
train_wavs = []
train_labels = []

valid_wavs = []
valid_labels = []

test_wavs = []
test_labels = []

start = time.time()

for root, dirs, files in os.walk("speech_commands"):
    if "_background_noise_" in root:
        continue
    for filename in files:
        if not filename.endswith('.wav'):
            continue
        command = root.split("/")[-1]
        if command not in label_set:
            continue
        else:
            label = label_set.index(command)
        full_name = os.path.join(root, filename)
        partial_path = '/'.join([command, filename])
        if partial_path in valid_list and len(valid_labels) < 1000:
            fs, waveform = wav.read(full_name)
            valid_wavs.append(waveform)
            valid_labels.append(label)
        elif partial_path in test_list and len(test_labels) < 1000:
            fs, waveform = wav.read(full_name)
            test_wavs.append(waveform)
            test_labels.append(label)
        elif train_labels.count(label) < nb_ex_per_class:
            fs, waveform = wav.read(full_name)
            train_wavs.append(waveform)
            train_labels.append(label)
# Print data statistics

print("Train files:" + str(len(train_wavs)))
print("Valid files:" + str(len(valid_wavs)))
print("Test files:" + str(len(test_wavs)))

end = time.time()

print("Time to output features: " + str(end-start))
# Out:
# Train files:9000
# Valid files:1000
# Test files:1000
# Time to output features: 15.523972034454346

# %% [markdown]
# The following cells create feature functions that have a .transform method that takes a waveform as input. You should not change the framerate parameter (the dataset is sampled at 16kHz).
# The other parameters are the following:
# * nfilt = number of mel-filters to average spectrograms
# * ncep = number of cepstral coefficients to use for MFCCs
# * do_dct = True to compute MFCC (otherwise mel-filterbanks are the output)
# * lowerf = lowest frequency spanned by the filters (and that will be taken into account by the features)
# * higherf = highest frequency spanned by the filters
# * alpha = parameter use for the pre-emphasis
# * frate = number of frames per second (1/frate is the stride of the windows in seconds)
# * wlen = length of windows in seconds
# * nfft = number of frequency bins used to compute the spectrogram
# * compression = the final compression performed on the mel-filterbanks (before DCT if you put do_dct=True)
# * do_deltas = compute the first derivatives of MFCC
# * do_deltasdeltas = compute the second derivatives of MFCC

# %%
framerate = 16000

# %% [markdown]
# # Mel-filterbanks function

# %%
melfbanks = spectral.Spectral(nfilt=20,
                    ncep=0,
                    do_dct=False,
                    lowerf=500,
                    upperf=5000,
                    alpha=0.6,
                    fs=framerate,
                    frate=100,
                    wlen=0.035,
                    nfft=512,
                    compression='log',
                    do_deltas=False,
                    do_deltasdeltas=False)

# %% [markdown]
# # MFCC function

# %%
mfcc = spectral.Spectral(nfilt=20,
                    ncep=8,
                    do_dct=True,
                    lowerf=500,
                    upperf=5000,
                    alpha=0.6,
                    fs=framerate,
                    frate=100,
                    wlen=0.035,
                    nfft=512,
                    compression='log',
                    do_deltas=True,
                    do_deltasdeltas=False)

# %% [markdown]
# # The following cell generates the features for train, valid and test from the waveforms

# %%
# Choose the feature function
feature_function = mfcc

start = time.time()
train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
end = time.time()

print("Time to output features: " + str(end-start))
# Out:
# Time to output features: 76.88936924934387

# %% [markdown]
# # Next cell trains a logistic regression on the speech features

# %%
#Logistic regression

# logreg = sklearn.linear_model.LogisticRegression(verbose=1, tol=1e-3, random_state=777) Does not scale
logreg = sklearn.linear_model.SGDClassifier(verbose=0,loss='log')
start = time.time()
logreg.fit(train_feats, train_labels)
end = time.time()
print("Training time: " + str(end-start))
# Out:
# Training time: 175.65673303604126

# %% [markdown]
# # You can now evaluate it on the validation set

# %%
print("Accuracy on valid set " + str(100*logreg.score(valid_feats, valid_labels)) + "%")
# Out:
# Accuracy on valid set 27.700000000000003%

# %% [markdown]
# # Next cell trains a neural network

# %%
neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                   verbose = True, random_state = 777, learning_rate='constant',
                                   learning_rate_init=0.01)

start = time.time()
neural_net.fit(train_feats, train_labels)
end = time.time()

print("Training time: " + str(end-start))
# Out:
# Iteration 1, loss = 6.94485150
# Iteration 2, loss = 3.42871732
# Iteration 3, loss = 3.35697762
# Iteration 4, loss = 3.31108984
# Iteration 5, loss = 3.27872877
# Iteration 6, loss = 3.20729534
# Iteration 7, loss = 3.10479517
# Iteration 8, loss = 3.00197160
# Iteration 9, loss = 2.91004780
# Iteration 10, loss = 2.85639851
# Iteration 11, loss = 2.76353350
# Iteration 12, loss = 2.74499268
# Iteration 13, loss = 2.72625564
# Iteration 14, loss = 2.69839360
# Iteration 15, loss = 2.66750167
# Iteration 16, loss = 2.66504909
# Iteration 17, loss = 2.65587916
# Iteration 18, loss = 2.64743339
# Iteration 19, loss = 2.61882639
# Iteration 20, loss = 2.60377881
# Iteration 21, loss = 2.65870029
# Iteration 22, loss = 2.65993147
# Iteration 23, loss = 2.61780236
# Iteration 24, loss = 2.58079745
# Iteration 25, loss = 2.59571686
# Iteration 26, loss = 2.55565721
# Iteration 27, loss = 2.55445514
# Iteration 28, loss = 2.53677680
# Iteration 29, loss = 2.54439032
# Iteration 30, loss = 2.57304469
# Iteration 31, loss = 2.56810709
# Iteration 32, loss = 2.52106601
# Iteration 33, loss = 2.53413695
# Iteration 34, loss = 2.54906235
# Iteration 35, loss = 2.54006772
# Iteration 36, loss = 2.53912936
# Iteration 37, loss = 2.52497300
# Iteration 38, loss = 2.53831102
# Iteration 39, loss = 2.54466391
# Iteration 40, loss = 2.57022046
# Iteration 41, loss = 2.51281325
# Iteration 42, loss = 2.47458177
# Iteration 43, loss = 2.42181612
# Iteration 44, loss = 2.41857986
# Iteration 45, loss = 2.44146864
# Iteration 46, loss = 2.41862814
# Iteration 47, loss = 2.40680133
# Iteration 48, loss = 2.38812098
# Iteration 49, loss = 2.41953545
# Iteration 50, loss = 2.34929217
# Iteration 51, loss = 2.36192321
# Iteration 52, loss = 2.37281394
# Iteration 53, loss = 2.39041161
# Iteration 54, loss = 2.43297602
# Iteration 55, loss = 2.32642580
# Iteration 56, loss = 2.33718757
# Iteration 57, loss = 2.28508330
# Iteration 58, loss = 2.24892460
# Iteration 59, loss = 2.27279914
# Iteration 60, loss = 2.25476316
# Iteration 61, loss = 2.27168840
# Iteration 62, loss = 2.33107667
# Iteration 63, loss = 2.26189742
# Iteration 64, loss = 2.24609581
# Iteration 65, loss = 2.24153141
# Iteration 66, loss = 2.22101670
# Iteration 67, loss = 2.24827867
# Iteration 68, loss = 2.20577818
# Iteration 69, loss = 2.17944801
# Iteration 70, loss = 2.15821165
# Iteration 71, loss = 2.19235926
# Iteration 72, loss = 2.16559781
# Iteration 73, loss = 2.17223020
# Iteration 74, loss = 2.14962466
# Iteration 75, loss = 2.17150219
# Iteration 76, loss = 2.13205648
# Iteration 77, loss = 2.10636022
# Iteration 78, loss = 2.13278012
# Iteration 79, loss = 2.12442421
# Iteration 80, loss = 2.08462657
# Iteration 81, loss = 2.12472578
# Iteration 82, loss = 2.05510707
# Iteration 83, loss = 2.07948877
# Iteration 84, loss = 2.09261803
# Iteration 85, loss = 2.04847340
# Iteration 86, loss = 2.03821441
# Iteration 87, loss = 2.05720883
# Iteration 88, loss = 2.01769935
# Iteration 89, loss = 2.01991189
# Iteration 90, loss = 2.03153013
# Iteration 91, loss = 2.06863484
# Iteration 92, loss = 2.01844493
# Iteration 93, loss = 2.01334180
# Iteration 94, loss = 1.96738048
# Iteration 95, loss = 1.94060849
# Iteration 96, loss = 1.95751539
# Iteration 97, loss = 1.89226834
# Iteration 98, loss = 1.91244568
# Iteration 99, loss = 1.96003777
# Iteration 100, loss = 1.96842927
# Iteration 101, loss = 1.89299684
# Iteration 102, loss = 1.87472993
# Iteration 103, loss = 1.89020730
# Iteration 104, loss = 1.89296219
# Iteration 105, loss = 1.87420420
# Iteration 106, loss = 1.84459213
# Iteration 107, loss = 1.87272899
# Iteration 108, loss = 1.91479077
# Iteration 109, loss = 1.88075882
# Iteration 110, loss = 1.84915247
# Iteration 111, loss = 1.86446241
# Iteration 112, loss = 1.86704037
# Iteration 113, loss = 1.84053066
# Iteration 114, loss = 1.85121904
# Iteration 115, loss = 1.86446809
# Iteration 116, loss = 1.90284980
# Iteration 117, loss = 1.79056957
# Iteration 118, loss = 1.81264360
# Iteration 119, loss = 1.80642685
# Iteration 120, loss = 1.80242348
# Iteration 121, loss = 1.77483815
# Iteration 122, loss = 1.86035617
# Iteration 123, loss = 1.79824042
# Iteration 124, loss = 1.89413910
# Iteration 125, loss = 2.00697665
# Iteration 126, loss = 2.10178871
# Iteration 127, loss = 1.98465090
# Iteration 128, loss = 1.81904732
# Iteration 129, loss = 1.83329950
# Iteration 130, loss = 1.77884018
# Iteration 131, loss = 1.77498071
# Iteration 132, loss = 1.77407993
# Iteration 133, loss = 1.73976458
# Iteration 134, loss = 1.87257533
# Iteration 135, loss = 1.81624226
# Iteration 136, loss = 1.81000402
# Iteration 137, loss = 1.75380848
# Iteration 138, loss = 1.72818449
# Iteration 139, loss = 1.75359103
# Iteration 140, loss = 1.79581090
# Iteration 141, loss = 1.73579849
# Iteration 142, loss = 1.70442791
# Iteration 143, loss = 1.78889126
# Iteration 144, loss = 1.80993490
# Iteration 145, loss = 1.74049929
# Iteration 146, loss = 1.72776788
# Iteration 147, loss = 1.69984315
# Iteration 148, loss = 1.71951258
# Iteration 149, loss = 1.71378273
# Iteration 150, loss = 1.71946521
# Iteration 151, loss = 1.69681165
# Iteration 152, loss = 1.66530082
# Iteration 153, loss = 1.72940583
# Iteration 154, loss = 1.76589240
# Iteration 155, loss = 1.73374435
# Iteration 156, loss = 1.66445923
# Iteration 157, loss = 1.73023888
# Iteration 158, loss = 1.70171280
# Iteration 159, loss = 1.67466096
# Iteration 160, loss = 1.67325447
# Iteration 161, loss = 1.62156680
# Iteration 162, loss = 1.62887295
# Iteration 163, loss = 1.69920921
# Iteration 164, loss = 1.69101625
# Iteration 165, loss = 1.65197008
# Iteration 166, loss = 1.67743917
# Iteration 167, loss = 1.67052893
# Iteration 168, loss = 1.66001277
# Iteration 169, loss = 1.65799775
# Iteration 170, loss = 1.64080421
# Iteration 171, loss = 1.62899467
# Iteration 172, loss = 1.65490408
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 108.78807234764099

# %% [markdown]
# # Evaluate it on the valid set

# %%
print("Accuracy on valid set " + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
# Out:
# Accuracy on valid set 0.0%

# %% [markdown]
# #Listen to a random waveform from the training set

# %%
random_idx = random.randint(0, len(valid_wavs))
random_wav = valid_wavs[random_idx]
IPython.display.Audio(random_wav, rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Visualize mel-filterbanks and MFCC

# %%
plt.imshow(melfbanks.transform(random_wav).transpose())
plt.gca().invert_yaxis()

# %%
plt.imshow(mfcc.transform(random_wav).transpose())
plt.gca().invert_yaxis()

# %% [markdown]
# # See what your classifier has predicted

# %%
print(label_set[neural_net.predict(valid_feats[random_idx][np.newaxis])[0]])
# Out:
# six

# %% [markdown]
# # What you are expected to do in this first part
# The first part of the TP above contains the different blocks that allow you to train speech commands recognizers. The results provided with the features and classifiers above are far from optimal. Indeed, the parameters for the speech features are poorly chosen.
#
# <!-- You are expected to explore various ways to improve their performance. Here are the main things to try:
# * The parameters of the speech features such as the min/max frequency or window size are poorly chosen, look inside the resources mentioned in the class to find the best parameters for mel-filterbanks and MFCC.
# * The logistic regression can be regularized in different ways (by controlling the C parameter) and you can try to find the best one
# * The neural net proposed is a shallow neural net, far from the best you can train. You should try bigger, deeper architectures, different types of regularization, activation functions, learning rate and so on
# * A standard way of improving generalization is to do mean-variance normalization on your data set. This is done by computing the mean and variance of each feature dimension on the entire training set, and then use it to normalize train, valid and test set
# * The dataset provides noises samples, either artificial (pink, white noise) or real (dishes, bike) in the folder _background_noise. You can try augmenting your dataset by adding noise to the waveforms before computing the features
# * The model is only trained on 300 examples per class, if your hardware allows it, try training on more examples
# * Feel free to also experiment with different classifiers -->
#
# * **Question 1.1**: Study the influence of the frequency range, hyper-parameter for the MFCC, on the validation performance. Choose only one model for this study. Does it concord with what we know about human speech characteristics (see material chap 7.5 Jurafsky ed 2) and sampling limitations of a continuous signal?
# * **Question 1.2**: Study the influence of the number of filters for the mel-log filterbanks and the number of cepstral coefficient for the MFCC, on the validation performance. Choose only one model for this study.
# Interpret this result with what you saw in class.
# * **Question 1.3**: Study the influence of the delta and delta_delta for the MFCC, on the validation performance. Choose only one model for this study.
# Interpret and comment this result.
# * **Question 1.4**: There are also other choices that influence the performance. Study the influence of the normalization after processing the features (per-channel and across channel normalization), the addition of noise, the training size. You can study other augmentation/pre-processing techniques. Focus on one model for this study. Interpret the results for each technique you studied.
# * **Question 1.5**: Study the influence on the performance of the model choices and their hyper-parameters. You can add other models of your choice. Focus on one type of features and one of the configurations based on previous questions. Comment your results.
# * **Question 1.6**: Based on the study on the validation set for the different precedent questions, report the performance for the test set for your best configuration. Feel free to run more experiments. Comment on the results (best model, best features, pre-processing). **Analyze the classes that are the most difficult to recognize**. You can try to push the performance and justify these new choices. The **grade will not depend on the performance of the final system**, but on how you experimented, tried different ideas, and comment on them.
#
#
# [Documentation for logistic regression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)
#
# [Documentation for neural network](http://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPClassifier.html)

# %% [markdown]
# **Question 1.1**

# %%
freqs=[(20,8000),(1000,5000),(100,5000),(1000,8000)]
labels=["full range of freq [100,8000]","human range of freq [1000,5000]","human range of freq with low freq [1000,5000]","human range of freq with high freq [1000,5000]"]
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
i=0
for lowerfreq,upperfreq in freqs:
  mfcc = spectral.Spectral(nfilt=20,
                      ncep=8,
                      do_dct=True,
                      lowerf=lowerfreq,
                      upperf=upperfreq,
                      alpha=0.6,
                      fs=framerate,
                      frate=100,
                      wlen=0.035,
                      nfft=512,
                      compression='log',
                      do_deltas=True,
                      do_deltasdeltas=False)
  # Choose the feature function
  feature_function = mfcc

  start = time.time()
  train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
  valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
  test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
  end = time.time()

  print("Time to output features: " + str(end-start))
  neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                    verbose = True, random_state = 777, learning_rate='constant',
                                    learning_rate_init=0.01)
  start = time.time()
  neural_net.fit(train_feats, train_labels)
  end = time.time()

  print("Training time: " + str(end-start))
  ax.plot(neural_net.loss_curve_, label=labels[i])
  i+=1
  print("Accuracy on valid set with frequency range  "+str(lowerfreq)+','+str(upperfreq)+': ' + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
fig.legend(ax.get_lines(), labels, ncol=3, loc="upper center")
plt.show()
# Out:
# Time to output features: 76.55389595031738
# Iteration 1, loss = 6.85246915
# Iteration 2, loss = 3.33823533
# Iteration 3, loss = 3.22261959
# Iteration 4, loss = 3.01736938
# Iteration 5, loss = 2.81871936
# Iteration 6, loss = 2.67034323
# Iteration 7, loss = 2.62492077
# Iteration 8, loss = 2.57951634
# Iteration 9, loss = 2.54791316
# Iteration 10, loss = 2.53582371
# Iteration 11, loss = 2.51177895
# Iteration 12, loss = 2.51089290
# Iteration 13, loss = 2.52169928
# Iteration 14, loss = 2.48730977
# Iteration 15, loss = 2.45429539
# Iteration 16, loss = 2.45969698
# Iteration 17, loss = 2.44995597
# Iteration 18, loss = 2.41522911
# Iteration 19, loss = 2.38705792
# Iteration 20, loss = 2.35820559
# Iteration 21, loss = 2.30978557
# Iteration 22, loss = 2.27954158
# Iteration 23, loss = 2.25338909
# Iteration 24, loss = 2.25430565
# Iteration 25, loss = 2.23326281
# Iteration 26, loss = 2.25722902
# Iteration 27, loss = 2.23461923
# Iteration 28, loss = 2.17704297
# Iteration 29, loss = 2.20087107
# Iteration 30, loss = 2.21993476
# Iteration 31, loss = 2.11831611
# Iteration 32, loss = 2.09375328
# Iteration 33, loss = 2.05059988
# Iteration 34, loss = 2.07931363
# Iteration 35, loss = 2.00618398
# Iteration 36, loss = 1.94611722
# Iteration 37, loss = 1.99450728
# Iteration 38, loss = 1.94603895
# Iteration 39, loss = 1.93416577
# Iteration 40, loss = 1.91813193
# Iteration 41, loss = 1.93327674
# Iteration 42, loss = 1.88054778
# Iteration 43, loss = 1.83299133
# Iteration 44, loss = 1.81927870
# Iteration 45, loss = 1.82280716
# Iteration 46, loss = 1.81642975
# Iteration 47, loss = 1.81102643
# Iteration 48, loss = 1.77713985
# Iteration 49, loss = 1.79298411
# Iteration 50, loss = 1.79276459
# Iteration 51, loss = 1.78309486
# Iteration 52, loss = 1.76002583
# Iteration 53, loss = 1.73348345
# Iteration 54, loss = 1.72148378
# Iteration 55, loss = 1.73969201
# Iteration 56, loss = 1.77442061
# Iteration 57, loss = 1.71201311
# Iteration 58, loss = 1.75183667
# Iteration 59, loss = 1.70430451
# Iteration 60, loss = 1.69598532
# Iteration 61, loss = 1.77155411
# Iteration 62, loss = 1.75659769
# Iteration 63, loss = 1.69472816
# Iteration 64, loss = 1.75290385
# Iteration 65, loss = 1.72801476
# Iteration 66, loss = 1.70845692
# Iteration 67, loss = 1.72887418
# Iteration 68, loss = 1.76261987
# Iteration 69, loss = 1.67851592
# Iteration 70, loss = 1.67824581
# Iteration 71, loss = 1.75189218
# Iteration 72, loss = 1.66759806
# Iteration 73, loss = 1.67722863
# Iteration 74, loss = 1.65541465
# Iteration 75, loss = 1.61880561
# Iteration 76, loss = 1.66233733
# Iteration 77, loss = 1.64748827
# Iteration 78, loss = 1.65807809
# Iteration 79, loss = 1.63661516
# Iteration 80, loss = 1.62759813
# Iteration 81, loss = 1.65160401
# Iteration 82, loss = 1.58906091
# Iteration 83, loss = 1.57738864
# Iteration 84, loss = 1.61816514
# Iteration 85, loss = 1.59182887
# Iteration 86, loss = 1.66347435
# Iteration 87, loss = 1.55046803
# Iteration 88, loss = 1.57227158
# Iteration 89, loss = 1.65941646
# Iteration 90, loss = 1.63435019
# Iteration 91, loss = 1.59151102
# Iteration 92, loss = 1.60899064
# Iteration 93, loss = 1.61034045
# Iteration 94, loss = 1.57902512
# Iteration 95, loss = 1.54052571
# Iteration 96, loss = 1.58200102
# Iteration 97, loss = 1.60344528
# Iteration 98, loss = 1.54834095
# Iteration 99, loss = 1.55464344
# Iteration 100, loss = 1.56343089
# Iteration 101, loss = 1.58037898
# Iteration 102, loss = 1.54878326
# Iteration 103, loss = 1.53583150
# Iteration 104, loss = 1.60138837
# Iteration 105, loss = 1.57309197
# Iteration 106, loss = 1.54885395
# Iteration 107, loss = 1.52395346
# Iteration 108, loss = 1.49717768
# Iteration 109, loss = 1.53163211
# Iteration 110, loss = 1.57037999
# Iteration 111, loss = 1.53808937
# Iteration 112, loss = 1.58379597
# Iteration 113, loss = 1.51530480
# Iteration 114, loss = 1.56895675
# Iteration 115, loss = 1.57069786
# Iteration 116, loss = 1.58180496
# Iteration 117, loss = 1.59329866
# Iteration 118, loss = 1.51593010
# Iteration 119, loss = 1.54440451
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 73.45945262908936
# Accuracy on valid set with frequency range  20,8000: 54.300000000000004%
# Time to output features: 74.79269075393677
# Iteration 1, loss = 5.54426735
# Iteration 2, loss = 3.34482745
# Iteration 3, loss = 3.20907443
# Iteration 4, loss = 3.13711659
# Iteration 5, loss = 3.07004738
# Iteration 6, loss = 3.01009728
# Iteration 7, loss = 2.95169243
# Iteration 8, loss = 2.82351796
# Iteration 9, loss = 2.75423908
# Iteration 10, loss = 2.77144371
# Iteration 11, loss = 2.70910770
# Iteration 12, loss = 2.70351171
# Iteration 13, loss = 2.67786258
# Iteration 14, loss = 2.70357193
# Iteration 15, loss = 2.64614209
# Iteration 16, loss = 2.65449019
# Iteration 17, loss = 2.66433932
# Iteration 18, loss = 2.62076045
# Iteration 19, loss = 2.62837294
# Iteration 20, loss = 2.60833935
# Iteration 21, loss = 2.61925612
# Iteration 22, loss = 2.62083729
# Iteration 23, loss = 2.58855900
# Iteration 24, loss = 2.55808745
# Iteration 25, loss = 2.53858438
# Iteration 26, loss = 2.54423910
# Iteration 27, loss = 2.53181387
# Iteration 28, loss = 2.51894573
# Iteration 29, loss = 2.50255917
# Iteration 30, loss = 2.51722497
# Iteration 31, loss = 2.50477010
# Iteration 32, loss = 2.46648716
# Iteration 33, loss = 2.48511858
# Iteration 34, loss = 2.49873067
# Iteration 35, loss = 2.49946269
# Iteration 36, loss = 2.62562675
# Iteration 37, loss = 2.58375991
# Iteration 38, loss = 2.49725913
# Iteration 39, loss = 2.48900199
# Iteration 40, loss = 2.42302691
# Iteration 41, loss = 2.43653623
# Iteration 42, loss = 2.41491507
# Iteration 43, loss = 2.41379586
# Iteration 44, loss = 2.41577829
# Iteration 45, loss = 2.40984763
# Iteration 46, loss = 2.39887926
# Iteration 47, loss = 2.37657262
# Iteration 48, loss = 2.39731967
# Iteration 49, loss = 2.40008592
# Iteration 50, loss = 2.38195180
# Iteration 51, loss = 2.36825373
# Iteration 52, loss = 2.34043763
# Iteration 53, loss = 2.33724344
# Iteration 54, loss = 2.36217582
# Iteration 55, loss = 2.35072548
# Iteration 56, loss = 2.35108780
# Iteration 57, loss = 2.35407285
# Iteration 58, loss = 2.30063023
# Iteration 59, loss = 2.28261040
# Iteration 60, loss = 2.26508156
# Iteration 61, loss = 2.26148940
# Iteration 62, loss = 2.32247543
# Iteration 63, loss = 2.24867042
# Iteration 64, loss = 2.26873112
# Iteration 65, loss = 2.29195031
# Iteration 66, loss = 2.23693820
# Iteration 67, loss = 2.23075407
# Iteration 68, loss = 2.23910714
# Iteration 69, loss = 2.19078946
# Iteration 70, loss = 2.19902383
# Iteration 71, loss = 2.19607763
# Iteration 72, loss = 2.18008448
# Iteration 73, loss = 2.19326030
# Iteration 74, loss = 2.18761457
# Iteration 75, loss = 2.17406086
# Iteration 76, loss = 2.16812914
# Iteration 77, loss = 2.15180691
# Iteration 78, loss = 2.16373304
# Iteration 79, loss = 2.14669495
# Iteration 80, loss = 2.15292374
# Iteration 81, loss = 2.13768773
# Iteration 82, loss = 2.12922185
# Iteration 83, loss = 2.10927211
# Iteration 84, loss = 2.14470989
# Iteration 85, loss = 2.12794847
# Iteration 86, loss = 2.19375104
# Iteration 87, loss = 2.19229399
# Iteration 88, loss = 2.16501055
# Iteration 89, loss = 2.15330228
# Iteration 90, loss = 2.13988073
# Iteration 91, loss = 2.30433100
# Iteration 92, loss = inf
# Iteration 93, loss = 2.30015229
# Iteration 94, loss = 2.21808121
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 60.2066707611084
# Accuracy on valid set with frequency range  1000,5000: 29.099999999999998%
# Time to output features: 74.2103431224823
# Iteration 1, loss = 6.09176938
# Iteration 2, loss = 3.38167399
# Iteration 3, loss = 3.33079000
# Iteration 4, loss = 3.22169373
# Iteration 5, loss = 3.04454680
# Iteration 6, loss = 2.90120794
# Iteration 7, loss = 2.76755944
# Iteration 8, loss = 2.69535685
# Iteration 9, loss = 2.61953009
# Iteration 10, loss = 2.60486960
# Iteration 11, loss = 2.58796378
# Iteration 12, loss = 2.57455864
# Iteration 13, loss = 2.56430842
# Iteration 14, loss = 2.50393152
# Iteration 15, loss = 2.48165134
# Iteration 16, loss = 2.44218965
# Iteration 17, loss = 2.45091364
# Iteration 18, loss = 2.44994843
# Iteration 19, loss = 2.38432994
# Iteration 20, loss = 2.36114383
# Iteration 21, loss = 2.33542924
# Iteration 22, loss = 2.34240523
# Iteration 23, loss = 2.35836441
# Iteration 24, loss = 2.27209974
# Iteration 25, loss = 2.26389215
# Iteration 26, loss = 2.17475948
# Iteration 27, loss = 2.12944036
# Iteration 28, loss = 2.14722289
# Iteration 29, loss = 2.10978644
# Iteration 30, loss = 2.03684636
# Iteration 31, loss = 2.03071910
# Iteration 32, loss = 2.05051056
# Iteration 33, loss = 2.00892662
# Iteration 34, loss = 2.03085765
# Iteration 35, loss = 1.99093632
# Iteration 36, loss = 1.97496224
# Iteration 37, loss = 2.01339213
# Iteration 38, loss = 1.97089523
# Iteration 39, loss = 2.03392405
# Iteration 40, loss = 2.01054301
# Iteration 41, loss = 2.02539552
# Iteration 42, loss = 1.95555822
# Iteration 43, loss = 1.94731980
# Iteration 44, loss = 1.93007258
# Iteration 45, loss = 1.96073616
# Iteration 46, loss = 1.94429509
# Iteration 47, loss = 1.91989087
# Iteration 48, loss = 1.89793403
# Iteration 49, loss = 1.92187495
# Iteration 50, loss = 1.92611967
# Iteration 51, loss = 1.92661941
# Iteration 52, loss = 1.89707083
# Iteration 53, loss = 1.89231416
# Iteration 54, loss = 1.90231035
# Iteration 55, loss = 1.89398480
# Iteration 56, loss = 1.93039445
# Iteration 57, loss = 1.88710455
# Iteration 58, loss = 1.84496634
# Iteration 59, loss = 1.84103003
# Iteration 60, loss = 1.84947185
# Iteration 61, loss = 1.86050439
# Iteration 62, loss = 1.86435099
# Iteration 63, loss = 1.86562722
# Iteration 64, loss = 1.83243321
# Iteration 65, loss = 1.90672949
# Iteration 66, loss = 1.92185545
# Iteration 67, loss = 1.88365606
# Iteration 68, loss = 1.91773420
# Iteration 69, loss = 1.98737181
# Iteration 70, loss = 2.00485234
# Iteration 71, loss = 1.87860209
# Iteration 72, loss = 1.84356387
# Iteration 73, loss = 1.87631792
# Iteration 74, loss = 1.83589195
# Iteration 75, loss = 1.81179464
# Iteration 76, loss = 1.84136024
# Iteration 77, loss = 1.85812406
# Iteration 78, loss = 1.82403702
# Iteration 79, loss = 1.80456612
# Iteration 80, loss = 1.78208799
# Iteration 81, loss = 1.80314321
# Iteration 82, loss = 1.77174046
# Iteration 83, loss = 1.77679152
# Iteration 84, loss = 1.81342190
# Iteration 85, loss = 1.79859804
# Iteration 86, loss = 1.79548864
# Iteration 87, loss = 1.78729430
# Iteration 88, loss = 1.78313904
# Iteration 89, loss = 1.79935017
# Iteration 90, loss = 1.74815477
# Iteration 91, loss = 1.76259835
# Iteration 92, loss = 1.74672190
# Iteration 93, loss = 1.74829526
# Iteration 94, loss = 1.71747268
# Iteration 95, loss = 1.72916121
# Iteration 96, loss = 1.78055210
# Iteration 97, loss = 1.75252824
# Iteration 98, loss = 1.72618962
# Iteration 99, loss = 1.75772317
# Iteration 100, loss = 1.76928037
# Iteration 101, loss = 1.74226720
# Iteration 102, loss = 1.72264792
# Iteration 103, loss = 1.72613354
# Iteration 104, loss = 1.74449619
# Iteration 105, loss = 1.74435328
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 65.5167715549469
# Accuracy on valid set with frequency range  100,5000: 44.6%
# Time to output features: 73.01217436790466
# Iteration 1, loss = 6.16445598
# Iteration 2, loss = 3.38988781
# Iteration 3, loss = 3.31519057
# Iteration 4, loss = 3.27784741
# Iteration 5, loss = 3.21638870
# Iteration 6, loss = 3.12742049
# Iteration 7, loss = 3.02205111
# Iteration 8, loss = 2.96697428
# Iteration 9, loss = 2.90701915
# Iteration 10, loss = 2.85435003
# Iteration 11, loss = 2.84898605
# Iteration 12, loss = 2.80613929
# Iteration 13, loss = 2.81002477
# Iteration 14, loss = 2.79250878
# Iteration 15, loss = 2.76048667
# Iteration 16, loss = 2.73990606
# Iteration 17, loss = 2.72109238
# Iteration 18, loss = 2.71293524
# Iteration 19, loss = 2.64466210
# Iteration 20, loss = 2.65969552
# Iteration 21, loss = 2.65807032
# Iteration 22, loss = 2.64847095
# Iteration 23, loss = 2.61806804
# Iteration 24, loss = 2.61400283
# Iteration 25, loss = 2.62762838
# Iteration 26, loss = 2.60637482
# Iteration 27, loss = 2.59264756
# Iteration 28, loss = 2.60240559
# Iteration 29, loss = 2.61463217
# Iteration 30, loss = 2.61165452
# Iteration 31, loss = 2.62289490
# Iteration 32, loss = 2.63921550
# Iteration 33, loss = 2.67405767
# Iteration 34, loss = 2.67753456
# Iteration 35, loss = 2.66875182
# Iteration 36, loss = 2.60933661
# Iteration 37, loss = 2.58350067
# Iteration 38, loss = 2.55563152
# Iteration 39, loss = 2.57417511
# Iteration 40, loss = 2.55882421
# Iteration 41, loss = 2.55158454
# Iteration 42, loss = 2.53334027
# Iteration 43, loss = 2.53047017
# Iteration 44, loss = 2.53319139
# Iteration 45, loss = 2.53333834
# Iteration 46, loss = 2.52391422
# Iteration 47, loss = 2.50637611
# Iteration 48, loss = 2.51227181
# Iteration 49, loss = 2.49291637
# Iteration 50, loss = 2.49365452
# Iteration 51, loss = 2.50443353
# Iteration 52, loss = 2.50188805
# Iteration 53, loss = 2.50107110
# Iteration 54, loss = 2.50498581
# Iteration 55, loss = 2.46979510
# Iteration 56, loss = 2.47386538
# Iteration 57, loss = 2.45582769
# Iteration 58, loss = 2.41782863
# Iteration 59, loss = 2.45976338
# Iteration 60, loss = 2.43192583
# Iteration 61, loss = 2.43620496
# Iteration 62, loss = 2.42857596
# Iteration 63, loss = 2.41722803
# Iteration 64, loss = 2.39265242
# Iteration 65, loss = 2.36168164
# Iteration 66, loss = 2.36466005
# Iteration 67, loss = 2.37250430
# Iteration 68, loss = 2.34866105
# Iteration 69, loss = 2.33198210
# Iteration 70, loss = 2.38973929
# Iteration 71, loss = 2.47259694
# Iteration 72, loss = 2.37213344
# Iteration 73, loss = 2.35017961
# Iteration 74, loss = 2.32492613
# Iteration 75, loss = 2.30032763
# Iteration 76, loss = 2.29256241
# Iteration 77, loss = 2.29629170
# Iteration 78, loss = 2.27425126
# Iteration 79, loss = 2.25946768
# Iteration 80, loss = 2.25149374
# Iteration 81, loss = 2.27533043
# Iteration 82, loss = 2.22698822
# Iteration 83, loss = 2.20606989
# Iteration 84, loss = 2.23882529
# Iteration 85, loss = 2.22587786
# Iteration 86, loss = 2.18253347
# Iteration 87, loss = 2.20308022
# Iteration 88, loss = 2.20057644
# Iteration 89, loss = 2.16266891
# Iteration 90, loss = 2.15245144
# Iteration 91, loss = 2.16068138
# Iteration 92, loss = 2.13439264
# Iteration 93, loss = 2.13594489
# Iteration 94, loss = 2.13233890
# Iteration 95, loss = 2.10909276
# Iteration 96, loss = 2.13225032
# Iteration 97, loss = 2.11316837
# Iteration 98, loss = 2.08106469
# Iteration 99, loss = 2.12039786
# Iteration 100, loss = 2.13602768
# Iteration 101, loss = 2.10560436
# Iteration 102, loss = 2.15127964
# Iteration 103, loss = 2.14301957
# Iteration 104, loss = 2.17996398
# Iteration 105, loss = 2.06813792
# Iteration 106, loss = 2.03506700
# Iteration 107, loss = 2.09126618
# Iteration 108, loss = 2.08119226
# Iteration 109, loss = 2.05751028
# Iteration 110, loss = 2.07320662
# Iteration 111, loss = 2.03223637
# Iteration 112, loss = 2.09458260
# Iteration 113, loss = 2.04930780
# Iteration 114, loss = 2.00451132
# Iteration 115, loss = 2.06791560
# Iteration 116, loss = 2.04397190
# Iteration 117, loss = 1.99352405
# Iteration 118, loss = 2.01747092
# Iteration 119, loss = 2.02873316
# Iteration 120, loss = 2.00594216
# Iteration 121, loss = 2.02921914
# Iteration 122, loss = 2.02878844
# Iteration 123, loss = 2.01682836
# Iteration 124, loss = 1.99208586
# Iteration 125, loss = 2.00373185
# Iteration 126, loss = 2.02502232
# Iteration 127, loss = 1.98719104
# Iteration 128, loss = 2.00554806
# Iteration 129, loss = 2.00571727
# Iteration 130, loss = 1.96631626
# Iteration 131, loss = 1.95033112
# Iteration 132, loss = 1.97360261
# Iteration 133, loss = 1.99586405
# Iteration 134, loss = 2.00024296
# Iteration 135, loss = 1.93785632
# Iteration 136, loss = 1.96141573
# Iteration 137, loss = 2.00345677
# Iteration 138, loss = 1.99808609
# Iteration 139, loss = 1.96743891
# Iteration 140, loss = 1.93274848
# Iteration 141, loss = 1.94317599
# Iteration 142, loss = 1.92694325
# Iteration 143, loss = 1.99953896
# Iteration 144, loss = 1.98399565
# Iteration 145, loss = 1.95217239
# Iteration 146, loss = 1.95003537
# Iteration 147, loss = 1.97032791
# Iteration 148, loss = 1.98253034
# Iteration 149, loss = inf
# Iteration 150, loss = 2.04388082
# Iteration 151, loss = inf
# Iteration 152, loss = 1.95002856
# Iteration 153, loss = 1.94428159
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 93.71924328804016
# Accuracy on valid set with frequency range  1000,8000: 32.800000000000004%

# %% [markdown]
# **Question 1.2**

# %%
# choosing nfilt for mel-filterbanks
lowerf= 20
upperf= 8000
nfilts=[5,20,50,120]
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
i=0
for nfilt in nfilts:
  mfb = spectral.Spectral(nfilt=nfilt,
                      ncep=8,
                      do_dct=True,
                      lowerf=lowerf,
                      upperf=upperf,
                      alpha=0.6,
                      fs=framerate,
                      frate=100,
                      wlen=0.035,
                      nfft=512,
                      compression='log',
                      do_deltas=True,
                      do_deltasdeltas=False)
  # Choose the feature function
  feature_function = mfb

  start = time.time()
  train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
  valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
  test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
  end = time.time()

  print("Time to output features: " + str(end-start))
  neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                    verbose = True, random_state = 777, learning_rate='constant',
                                    learning_rate_init=0.01)
  start = time.time()
  neural_net.fit(train_feats, train_labels)
  end = time.time()

  print("Training time: " + str(end-start))
  ax.plot(neural_net.loss_curve_, label=nfilts[i])
  i+=1
  print("Accuracy on valid set with a number of  "+str(nfilt) +' filter: ' + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
fig.legend(ax.get_lines(), labels, ncol=3, loc="upper center")
plt.show()
# Out:
# Time to output features: 65.27712988853455
# Iteration 1, loss = 6.40198073
# Iteration 2, loss = 3.42812258
# Iteration 3, loss = 3.38960756
# Iteration 4, loss = 3.35924390
# Iteration 5, loss = 3.31626450
# Iteration 6, loss = 3.28775409
# Iteration 7, loss = 3.24921478
# Iteration 8, loss = 3.22439610
# Iteration 9, loss = 3.20080412
# Iteration 10, loss = 3.19164701
# Iteration 11, loss = 3.18341106
# Iteration 12, loss = 3.17620055
# Iteration 13, loss = 3.15114121
# Iteration 14, loss = 3.08238778
# Iteration 15, loss = 3.03195810
# Iteration 16, loss = 3.00505295
# Iteration 17, loss = 2.98452912
# Iteration 18, loss = 3.00452543
# Iteration 19, loss = 2.94977685
# Iteration 20, loss = 2.91655292
# Iteration 21, loss = 2.87651747
# Iteration 22, loss = 2.81987112
# Iteration 23, loss = 2.80425968
# Iteration 24, loss = 2.78913348
# Iteration 25, loss = 2.77871670
# Iteration 26, loss = 2.81056345
# Iteration 27, loss = 2.82530903
# Iteration 28, loss = 2.82740071
# Iteration 29, loss = 2.83781111
# Iteration 30, loss = 2.78679726
# Iteration 31, loss = 2.77874754
# Iteration 32, loss = 2.76096870
# Iteration 33, loss = 2.75119725
# Iteration 34, loss = 2.73594245
# Iteration 35, loss = 2.73771118
# Iteration 36, loss = 2.73072375
# Iteration 37, loss = 2.71563138
# Iteration 38, loss = 2.75159364
# Iteration 39, loss = 2.71412398
# Iteration 40, loss = 2.71745030
# Iteration 41, loss = 2.72094769
# Iteration 42, loss = 2.74952857
# Iteration 43, loss = 2.72630731
# Iteration 44, loss = 2.71714902
# Iteration 45, loss = 2.72629421
# Iteration 46, loss = 2.72457898
# Iteration 47, loss = 2.72656586
# Iteration 48, loss = 2.70709742
# Iteration 49, loss = 2.70272119
# Iteration 50, loss = 2.70690624
# Iteration 51, loss = 2.69266196
# Iteration 52, loss = 2.70094705
# Iteration 53, loss = 2.67345529
# Iteration 54, loss = 2.64913243
# Iteration 55, loss = 2.66799629
# Iteration 56, loss = 2.69691741
# Iteration 57, loss = 2.70510351
# Iteration 58, loss = 2.66627864
# Iteration 59, loss = 2.60708054
# Iteration 60, loss = 2.59549457
# Iteration 61, loss = 2.58032400
# Iteration 62, loss = 2.61362355
# Iteration 63, loss = 2.57498702
# Iteration 64, loss = 2.57738500
# Iteration 65, loss = 2.55861790
# Iteration 66, loss = 2.52969270
# Iteration 67, loss = 2.57185402
# Iteration 68, loss = 2.58440894
# Iteration 69, loss = 2.56852557
# Iteration 70, loss = 2.58155467
# Iteration 71, loss = 2.55343024
# Iteration 72, loss = 2.56159471
# Iteration 73, loss = 2.54912388
# Iteration 74, loss = 2.56772397
# Iteration 75, loss = 2.55116026
# Iteration 76, loss = 2.55483628
# Iteration 77, loss = 2.53277597
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 51.07211995124817
# Accuracy on valid set with a number of  5 filter: 37.1%
# Time to output features: 77.44819164276123
# Iteration 1, loss = 6.85246915
# Iteration 2, loss = 3.33823533
# Iteration 3, loss = 3.22261959
# Iteration 4, loss = 3.01736938
# Iteration 5, loss = 2.81871936
# Iteration 6, loss = 2.67034323
# Iteration 7, loss = 2.62492077
# Iteration 8, loss = 2.57951634
# Iteration 9, loss = 2.54791316
# Iteration 10, loss = 2.53582371
# Iteration 11, loss = 2.51177895
# Iteration 12, loss = 2.51089290
# Iteration 13, loss = 2.52169928
# Iteration 14, loss = 2.48730977
# Iteration 15, loss = 2.45429539
# Iteration 16, loss = 2.45969698
# Iteration 17, loss = 2.44995597
# Iteration 18, loss = 2.41522911
# Iteration 19, loss = 2.38705792
# Iteration 20, loss = 2.35820559
# Iteration 21, loss = 2.30978557
# Iteration 22, loss = 2.27954158
# Iteration 23, loss = 2.25338909
# Iteration 24, loss = 2.25430565
# Iteration 25, loss = 2.23326281
# Iteration 26, loss = 2.25722902
# Iteration 27, loss = 2.23461923
# Iteration 28, loss = 2.17704297
# Iteration 29, loss = 2.20087107
# Iteration 30, loss = 2.21993476
# Iteration 31, loss = 2.11831611
# Iteration 32, loss = 2.09375328
# Iteration 33, loss = 2.05059988
# Iteration 34, loss = 2.07931363
# Iteration 35, loss = 2.00618398
# Iteration 36, loss = 1.94611722
# Iteration 37, loss = 1.99450728
# Iteration 38, loss = 1.94603895
# Iteration 39, loss = 1.93416577
# Iteration 40, loss = 1.91813193
# Iteration 41, loss = 1.93327674
# Iteration 42, loss = 1.88054778
# Iteration 43, loss = 1.83299133
# Iteration 44, loss = 1.81927870
# Iteration 45, loss = 1.82280716
# Iteration 46, loss = 1.81642975
# Iteration 47, loss = 1.81102643
# Iteration 48, loss = 1.77713985
# Iteration 49, loss = 1.79298411
# Iteration 50, loss = 1.79276459
# Iteration 51, loss = 1.78309486
# Iteration 52, loss = 1.76002583
# Iteration 53, loss = 1.73348345
# Iteration 54, loss = 1.72148378
# Iteration 55, loss = 1.73969201
# Iteration 56, loss = 1.77442061
# Iteration 57, loss = 1.71201311
# Iteration 58, loss = 1.75183667
# Iteration 59, loss = 1.70430451
# Iteration 60, loss = 1.69598532
# Iteration 61, loss = 1.77155411
# Iteration 62, loss = 1.75659769
# Iteration 63, loss = 1.69472816
# Iteration 64, loss = 1.75290385
# Iteration 65, loss = 1.72801476
# Iteration 66, loss = 1.70845692
# Iteration 67, loss = 1.72887418
# Iteration 68, loss = 1.76261987
# Iteration 69, loss = 1.67851592
# Iteration 70, loss = 1.67824581
# Iteration 71, loss = 1.75189218
# Iteration 72, loss = 1.66759806
# Iteration 73, loss = 1.67722863
# Iteration 74, loss = 1.65541465
# Iteration 75, loss = 1.61880561
# Iteration 76, loss = 1.66233733
# Iteration 77, loss = 1.64748827
# Iteration 78, loss = 1.65807809
# Iteration 79, loss = 1.63661516
# Iteration 80, loss = 1.62759813
# Iteration 81, loss = 1.65160401
# Iteration 82, loss = 1.58906091
# Iteration 83, loss = 1.57738864
# Iteration 84, loss = 1.61816514
# Iteration 85, loss = 1.59182887
# Iteration 86, loss = 1.66347435
# Iteration 87, loss = 1.55046803
# Iteration 88, loss = 1.57227158
# Iteration 89, loss = 1.65941646
# Iteration 90, loss = 1.63435019
# Iteration 91, loss = 1.59151102
# Iteration 92, loss = 1.60899064
# Iteration 93, loss = 1.61034045
# Iteration 94, loss = 1.57902512
# Iteration 95, loss = 1.54052571
# Iteration 96, loss = 1.58200102
# Iteration 97, loss = 1.60344528
# Iteration 98, loss = 1.54834095
# Iteration 99, loss = 1.55464344
# Iteration 100, loss = 1.56343089
# Iteration 101, loss = 1.58037898
# Iteration 102, loss = 1.54878326
# Iteration 103, loss = 1.53583150
# Iteration 104, loss = 1.60138837
# Iteration 105, loss = 1.57309197
# Iteration 106, loss = 1.54885395
# Iteration 107, loss = 1.52395346
# Iteration 108, loss = 1.49717768
# Iteration 109, loss = 1.53163211
# Iteration 110, loss = 1.57037999
# Iteration 111, loss = 1.53808937
# Iteration 112, loss = 1.58379597
# Iteration 113, loss = 1.51530480
# Iteration 114, loss = 1.56895675
# Iteration 115, loss = 1.57069786
# Iteration 116, loss = 1.58180496
# Iteration 117, loss = 1.59329866
# Iteration 118, loss = 1.51593010
# Iteration 119, loss = 1.54440451
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 81.0266170501709
# Accuracy on valid set with a number of  20 filter: 54.300000000000004%
# Time to output features: 126.36096286773682
# Iteration 1, loss = 6.29849610
# Iteration 2, loss = 3.22415742
# Iteration 3, loss = 3.06999556
# Iteration 4, loss = 2.97365805
# Iteration 5, loss = 2.84898454
# Iteration 6, loss = 2.73734976
# Iteration 7, loss = 2.67652794
# Iteration 8, loss = 2.59051170
# Iteration 9, loss = 2.53039239
# Iteration 10, loss = 2.47357255
# Iteration 11, loss = 2.42129344
# Iteration 12, loss = 2.38522587
# Iteration 13, loss = 2.36986406
# Iteration 14, loss = 2.33741081
# Iteration 15, loss = 2.30171298
# Iteration 16, loss = 2.30290234
# Iteration 17, loss = 2.30105658
# Iteration 18, loss = 2.26179351
# Iteration 19, loss = 2.22264907
# Iteration 20, loss = 2.19491069
# Iteration 21, loss = 2.13306236
# Iteration 22, loss = 2.16584070
# Iteration 23, loss = 2.11803289
# Iteration 24, loss = 2.20843240
# Iteration 25, loss = 2.13241463
# Iteration 26, loss = 2.08266254
# Iteration 27, loss = 2.05889616
# Iteration 28, loss = 2.04581153
# Iteration 29, loss = 2.02285641
# Iteration 30, loss = 2.01621774
# Iteration 31, loss = 1.99503480
# Iteration 32, loss = 1.98629464
# Iteration 33, loss = 2.04230587
# Iteration 34, loss = 1.95836450
# Iteration 35, loss = 1.97652985
# Iteration 36, loss = 1.95172798
# Iteration 37, loss = 1.94100500
# Iteration 38, loss = 1.94137982
# Iteration 39, loss = 1.94152767
# Iteration 40, loss = 1.90235976
# Iteration 41, loss = 1.87496302
# Iteration 42, loss = 1.82189029
# Iteration 43, loss = 1.84212092
# Iteration 44, loss = 1.81413406
# Iteration 45, loss = 1.82070628
# Iteration 46, loss = 1.87539785
# Iteration 47, loss = 1.81476703
# Iteration 48, loss = 1.77965249
# Iteration 49, loss = 1.79048582
# Iteration 50, loss = 1.76167985
# Iteration 51, loss = 1.75913291
# Iteration 52, loss = 1.76913030
# Iteration 53, loss = 1.75889243
# Iteration 54, loss = 1.74845222
# Iteration 55, loss = 1.74894506
# Iteration 56, loss = 1.74992598
# Iteration 57, loss = 1.69893142
# Iteration 58, loss = 1.71233219
# Iteration 59, loss = 1.72396600
# Iteration 60, loss = 1.70038489
# Iteration 61, loss = 1.71970573
# Iteration 62, loss = 1.69598486
# Iteration 63, loss = 1.71489820
# Iteration 64, loss = 1.69934605
# Iteration 65, loss = 1.69325971
# Iteration 66, loss = 1.66255436
# Iteration 67, loss = 1.68842411
# Iteration 68, loss = 1.73691740
# Iteration 69, loss = 1.75610412
# Iteration 70, loss = 1.70709095
# Iteration 71, loss = 1.70197698
# Iteration 72, loss = 1.70936698
# Iteration 73, loss = 1.65486094
# Iteration 74, loss = 1.61599303
# Iteration 75, loss = 1.62929691
# Iteration 76, loss = 1.58002433
# Iteration 77, loss = 1.59907109
# Iteration 78, loss = 1.57957009
# Iteration 79, loss = 1.60958976
# Iteration 80, loss = 1.62665215
# Iteration 81, loss = 1.62318172
# Iteration 82, loss = 1.57593665
# Iteration 83, loss = 1.57260420
# Iteration 84, loss = 1.62950631
# Iteration 85, loss = 1.60958814
# Iteration 86, loss = 1.58380519
# Iteration 87, loss = 1.57269552
# Iteration 88, loss = 1.54608229
# Iteration 89, loss = 1.54100621
# Iteration 90, loss = 1.56585104
# Iteration 91, loss = 1.52513437
# Iteration 92, loss = 1.53249197
# Iteration 93, loss = 1.52993326
# Iteration 94, loss = 1.50241844
# Iteration 95, loss = 1.52853538
# Iteration 96, loss = 1.53073745
# Iteration 97, loss = 1.48840587
# Iteration 98, loss = 1.47673522
# Iteration 99, loss = 1.45524447
# Iteration 100, loss = 1.51530610
# Iteration 101, loss = 1.52165079
# Iteration 102, loss = 1.47366390
# Iteration 103, loss = 1.52264125
# Iteration 104, loss = 1.58821009
# Iteration 105, loss = 1.56852187
# Iteration 106, loss = 1.48061628
# Iteration 107, loss = 1.54280141
# Iteration 108, loss = 1.45724163
# Iteration 109, loss = 1.42676736
# Iteration 110, loss = 1.46439493
# Iteration 111, loss = 1.47048773
# Iteration 112, loss = 1.46161948
# Iteration 113, loss = 1.42164888
# Iteration 114, loss = 1.48424360
# Iteration 115, loss = 1.41363114
# Iteration 116, loss = 1.42926244
# Iteration 117, loss = 1.43126165
# Iteration 118, loss = 1.43760641
# Iteration 119, loss = 1.39571408
# Iteration 120, loss = 1.39813936
# Iteration 121, loss = 1.38408530
# Iteration 122, loss = 1.42897790
# Iteration 123, loss = 1.42795265
# Iteration 124, loss = 1.41055394
# Iteration 125, loss = 1.39485821
# Iteration 126, loss = 1.41949016
# Iteration 127, loss = 1.36906117
# Iteration 128, loss = 1.39178261
# Iteration 129, loss = 1.34973328
# Iteration 130, loss = 1.37308693
# Iteration 131, loss = 1.36179742
# Iteration 132, loss = 1.36971850
# Iteration 133, loss = 1.38643004
# Iteration 134, loss = 1.44080411
# Iteration 135, loss = 1.36409266
# Iteration 136, loss = 1.41936880
# Iteration 137, loss = 1.41680129
# Iteration 138, loss = 1.39023397
# Iteration 139, loss = 1.36601409
# Iteration 140, loss = 1.34637050
# Iteration 141, loss = 1.32091667
# Iteration 142, loss = 1.39083880
# Iteration 143, loss = 1.40818122
# Iteration 144, loss = 1.36519794
# Iteration 145, loss = 1.35078439
# Iteration 146, loss = 1.36455411
# Iteration 147, loss = 1.33293841
# Iteration 148, loss = 1.36629952
# Iteration 149, loss = 1.38165223
# Iteration 150, loss = 1.33117031
# Iteration 151, loss = 1.33011611
# Iteration 152, loss = 1.31244124
# Iteration 153, loss = 1.31806035
# Iteration 154, loss = 1.40908568
# Iteration 155, loss = 1.42598243
# Iteration 156, loss = 1.45084246
# Iteration 157, loss = 1.65833018
# Iteration 158, loss = 1.49458752
# Iteration 159, loss = 1.36187139
# Iteration 160, loss = 1.30797106
# Iteration 161, loss = 1.34366719
# Iteration 162, loss = 1.27668534
# Iteration 163, loss = 1.31096484
# Iteration 164, loss = 1.29272540
# Iteration 165, loss = 1.30672603
# Iteration 166, loss = 1.30469748
# Iteration 167, loss = 1.29950333
# Iteration 168, loss = 1.31485668
# Iteration 169, loss = 1.31308770
# Iteration 170, loss = 1.30623786
# Iteration 171, loss = 1.26494447
# Iteration 172, loss = 1.31642732
# Iteration 173, loss = 1.37876949
# Iteration 174, loss = 1.33066627
# Iteration 175, loss = 1.29288369
# Iteration 176, loss = 1.30881758
# Iteration 177, loss = 1.26009436
# Iteration 178, loss = 1.27898678
# Iteration 179, loss = 1.29675752
# Iteration 180, loss = 1.32463618
# Iteration 181, loss = 1.27371456
# Iteration 182, loss = 1.24221347
# Iteration 183, loss = 1.32042770
# Iteration 184, loss = 1.28826883
# Iteration 185, loss = 1.31545121
# Iteration 186, loss = 1.26020281
# Iteration 187, loss = 1.24752061
# Iteration 188, loss = 1.24415153
# Iteration 189, loss = 1.26000668
# Iteration 190, loss = 1.23456295
# Iteration 191, loss = 1.24793033
# Iteration 192, loss = 1.24164273
# Iteration 193, loss = 1.29366934
# Iteration 194, loss = 1.26431455
# Iteration 195, loss = 1.29046969
# Iteration 196, loss = 1.24448373
# Iteration 197, loss = 1.21507744
# Iteration 198, loss = 1.20047720
# Iteration 199, loss = 1.23360487
# Iteration 200, loss = 1.25376550
# Training time: 133.28197026252747
# Accuracy on valid set with a number of  50 filter: 52.800000000000004%
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Time to output features: 134.9662845134735
# Iteration 1, loss = 6.14478645
# Iteration 2, loss = 3.42631801
# Iteration 3, loss = 3.40189476
# Iteration 4, loss = 3.38093601
# Iteration 5, loss = 3.35528034
# Iteration 6, loss = 3.29167231
# Iteration 7, loss = 3.19743481
# Iteration 8, loss = 3.11457575
# Iteration 9, loss = 3.05131684
# Iteration 10, loss = 3.00573989
# Iteration 11, loss = 2.98398394
# Iteration 12, loss = 2.98792665
# Iteration 13, loss = 2.96107559
# Iteration 14, loss = 2.92182461
# Iteration 15, loss = 2.92710800
# Iteration 16, loss = 2.92787931
# Iteration 17, loss = 2.91532561
# Iteration 18, loss = 2.91513679
# Iteration 19, loss = 2.88877994
# Iteration 20, loss = 2.88946853
# Iteration 21, loss = 2.88524727
# Iteration 22, loss = 2.90195704
# Iteration 23, loss = 2.87171104
# Iteration 24, loss = 2.88546187
# Iteration 25, loss = 2.86435310
# Iteration 26, loss = 2.86286912
# Iteration 27, loss = 2.87801422
# Iteration 28, loss = 2.85305791
# Iteration 29, loss = 2.93248553
# Iteration 30, loss = 2.79579002
# Iteration 31, loss = 2.78318231
# Iteration 32, loss = 2.75497959
# Iteration 33, loss = 2.72510760
# Iteration 34, loss = 2.71802131
# Iteration 35, loss = 2.69941968
# Iteration 36, loss = 2.70228226
# Iteration 37, loss = 2.72319957
# Iteration 38, loss = 2.67558251
# Iteration 39, loss = 2.69062403
# Iteration 40, loss = 2.70063496
# Iteration 41, loss = 2.67441399
# Iteration 42, loss = 2.69522180
# Iteration 43, loss = 2.68382575
# Iteration 44, loss = 2.66069761
# Iteration 45, loss = 2.68433280
# Iteration 46, loss = 2.66799773
# Iteration 47, loss = 2.65170327
# Iteration 48, loss = 2.65749148
# Iteration 49, loss = 2.64243588
# Iteration 50, loss = 2.64514375
# Iteration 51, loss = 2.62145517
# Iteration 52, loss = 2.63347707
# Iteration 53, loss = 2.63320237
# Iteration 54, loss = 2.56708294
# Iteration 55, loss = 2.62515133
# Iteration 56, loss = 2.55381981
# Iteration 57, loss = 2.51727303
# Iteration 58, loss = 2.51274544
# Iteration 59, loss = 2.49925185
# Iteration 60, loss = 2.50293843
# Iteration 61, loss = 2.48919171
# Iteration 62, loss = 2.46974641
# Iteration 63, loss = 2.47114027
# Iteration 64, loss = 2.47599352
# Iteration 65, loss = 2.49122258
# Iteration 66, loss = 2.52495417
# Iteration 67, loss = 2.50520403
# Iteration 68, loss = 2.51755387
# Iteration 69, loss = 2.47816074
# Iteration 70, loss = 2.42627231
# Iteration 71, loss = 2.42094327
# Iteration 72, loss = 2.41415541
# Iteration 73, loss = 2.42364119
# Iteration 74, loss = 2.39113224
# Iteration 75, loss = 2.37779211
# Iteration 76, loss = 2.41790472
# Iteration 77, loss = 2.40351594
# Iteration 78, loss = 2.35882758
# Iteration 79, loss = 2.37187895
# Iteration 80, loss = 2.37024485
# Iteration 81, loss = 2.32125770
# Iteration 82, loss = 2.30940574
# Iteration 83, loss = 2.25198061
# Iteration 84, loss = 2.26001523
# Iteration 85, loss = 2.24836820
# Iteration 86, loss = 2.30870802
# Iteration 87, loss = 2.23838025
# Iteration 88, loss = 2.19252340
# Iteration 89, loss = 2.20954841
# Iteration 90, loss = 2.17039812
# Iteration 91, loss = 2.17785470
# Iteration 92, loss = 2.15401599
# Iteration 93, loss = 2.13807647
# Iteration 94, loss = 2.12527642
# Iteration 95, loss = 2.10045397
# Iteration 96, loss = 2.12620515
# Iteration 97, loss = 2.13991633
# Iteration 98, loss = 2.10216719
# Iteration 99, loss = 2.10571606
# Iteration 100, loss = 2.13334608
# Iteration 101, loss = 2.11952482
# Iteration 102, loss = 2.07533096
# Iteration 103, loss = 2.10583376
# Iteration 104, loss = 2.13639655
# Iteration 105, loss = 2.10408224
# Iteration 106, loss = 2.08245401
# Iteration 107, loss = 2.08257912
# Iteration 108, loss = 2.05906718
# Iteration 109, loss = 2.04489543
# Iteration 110, loss = 2.04634335
# Iteration 111, loss = 2.04872989
# Iteration 112, loss = 2.06228228
# Iteration 113, loss = 2.03508916
# Iteration 114, loss = 2.06115939
# Iteration 115, loss = 2.03888011
# Iteration 116, loss = 2.01424714
# Iteration 117, loss = 2.01716783
# Iteration 118, loss = 2.02489351
# Iteration 119, loss = 2.00452980
# Iteration 120, loss = 2.00746168
# Iteration 121, loss = 2.01761913
# Iteration 122, loss = 2.01119564
# Iteration 123, loss = 2.01431915
# Iteration 124, loss = 2.03598730
# Iteration 125, loss = 2.01238940
# Iteration 126, loss = 1.97458412
# Iteration 127, loss = 1.99133430
# Iteration 128, loss = 1.95658168
# Iteration 129, loss = 2.01122021
# Iteration 130, loss = 2.00541527
# Iteration 131, loss = 2.00342717
# Iteration 132, loss = 1.97175994
# Iteration 133, loss = 1.94503701
# Iteration 134, loss = 1.94113459
# Iteration 135, loss = 1.94326150
# Iteration 136, loss = 1.97144816
# Iteration 137, loss = 1.96453483
# Iteration 138, loss = 1.97408665
# Iteration 139, loss = 2.03040425
# Iteration 140, loss = 2.13272924
# Iteration 141, loss = 2.02356361
# Iteration 142, loss = 2.02854555
# Iteration 143, loss = 1.94420967
# Iteration 144, loss = 1.93605872
# Iteration 145, loss = 1.92777192
# Iteration 146, loss = 1.97976854
# Iteration 147, loss = 1.94906662
# Iteration 148, loss = 1.91058190
# Iteration 149, loss = 1.98560852
# Iteration 150, loss = 1.99725444
# Iteration 151, loss = 1.94939569
# Iteration 152, loss = 1.94246114
# Iteration 153, loss = 1.94986256
# Iteration 154, loss = 1.98979216
# Iteration 155, loss = 1.93280845
# Iteration 156, loss = 1.93337165
# Iteration 157, loss = 1.95722581
# Iteration 158, loss = 1.92687819
# Iteration 159, loss = 1.94843537
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 105.78894567489624
# Accuracy on valid set with a number of  120 filter: 39.800000000000004%

# %%
nceps=[2,6,8,12,16,24]
lowerf= 20
upperf= 8000
nfilt = 20
fig, ax = plt.subplots(1, 1, figsize=(15, 10))
i=0
for ncep in nceps:
  mfb = spectral.Spectral(nfilt=nfilt,
                      ncep=ncep,
                      do_dct=True,
                      lowerf=lowerf,
                      upperf=upperf,
                      alpha=0.6,
                      fs=framerate,
                      frate=100,
                      wlen=0.035,
                      nfft=512,
                      compression='log',
                      do_deltas=True,
                      do_deltasdeltas=False)
  # Choose the feature function
  feature_function = mfb

  start = time.time()
  train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
  valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
  test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
  end = time.time()

  print("Time to output features: " + str(end-start))
  neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                    verbose = True, random_state = 777, learning_rate='constant',
                                    learning_rate_init=0.01)
  start = time.time()
  neural_net.fit(train_feats, train_labels)
  end = time.time()

  print("Training time: " + str(end-start))
  ax.plot(neural_net.loss_curve_, label= str(nceps[i]))
  i+=1
  print("Accuracy on valid set with a cepstral coef of  "+str(ncep) +': ' + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
fig.legend(ax.get_lines(), labels, ncol=3, loc="upper center")
plt.show()
# Out:
# Time to output features: 74.69146919250488
# Iteration 1, loss = 5.96329790
# Iteration 2, loss = 3.42982226
# Iteration 3, loss = 3.40351647
# Iteration 4, loss = 3.39928964
# Iteration 5, loss = 3.39155716
# Iteration 6, loss = 3.38839675
# Iteration 7, loss = 3.38638553
# Iteration 8, loss = 3.38675390
# Iteration 9, loss = 3.38715591
# Iteration 10, loss = 3.38207309
# Iteration 11, loss = 3.38022203
# Iteration 12, loss = 3.31300036
# Iteration 13, loss = 3.19903087
# Iteration 14, loss = 3.12506635
# Iteration 15, loss = 3.05317347
# Iteration 16, loss = 2.98960785
# Iteration 17, loss = 2.95235874
# Iteration 18, loss = 2.93717218
# Iteration 19, loss = 2.90179026
# Iteration 20, loss = 2.87930204
# Iteration 21, loss = 2.87687484
# Iteration 22, loss = 2.82970928
# Iteration 23, loss = 2.80839825
# Iteration 24, loss = 2.78993914
# Iteration 25, loss = 2.75780741
# Iteration 26, loss = 2.75618074
# Iteration 27, loss = 2.74857896
# Iteration 28, loss = 2.74706250
# Iteration 29, loss = 2.75918315
# Iteration 30, loss = 2.70844514
# Iteration 31, loss = 2.71307014
# Iteration 32, loss = 2.72325171
# Iteration 33, loss = 2.68839831
# Iteration 34, loss = 2.69928499
# Iteration 35, loss = 2.70993671
# Iteration 36, loss = 2.68079367
# Iteration 37, loss = 2.68408714
# Iteration 38, loss = 2.69367760
# Iteration 39, loss = 2.66258862
# Iteration 40, loss = 2.67144122
# Iteration 41, loss = 2.66811069
# Iteration 42, loss = 2.66242731
# Iteration 43, loss = 2.67200549
# Iteration 44, loss = 2.63239090
# Iteration 45, loss = 2.67988539
# Iteration 46, loss = 2.68303328
# Iteration 47, loss = 2.66184359
# Iteration 48, loss = 2.62980195
# Iteration 49, loss = 2.60021029
# Iteration 50, loss = 2.56930196
# Iteration 51, loss = 2.58006356
# Iteration 52, loss = 2.60536476
# Iteration 53, loss = 2.57883133
# Iteration 54, loss = 2.60307685
# Iteration 55, loss = 2.57897734
# Iteration 56, loss = 2.60113277
# Iteration 57, loss = 2.57481411
# Iteration 58, loss = 2.58269160
# Iteration 59, loss = 2.56276364
# Iteration 60, loss = 2.53685356
# Iteration 61, loss = 2.54882019
# Iteration 62, loss = 2.51867133
# Iteration 63, loss = 2.47808558
# Iteration 64, loss = 2.54087733
# Iteration 65, loss = 2.56159884
# Iteration 66, loss = 2.51133307
# Iteration 67, loss = 2.49681646
# Iteration 68, loss = 2.53630109
# Iteration 69, loss = 2.52202986
# Iteration 70, loss = 2.50906655
# Iteration 71, loss = 2.51728140
# Iteration 72, loss = 2.47933565
# Iteration 73, loss = 2.52248709
# Iteration 74, loss = 2.49200114
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 50.64708113670349
# Accuracy on valid set with a cepstral coef of  2: 47.699999999999996%
# Time to output features: 75.08259224891663
# Iteration 1, loss = 5.92356130
# Iteration 2, loss = 3.40603068
# Iteration 3, loss = 3.26930919
# Iteration 4, loss = 3.12914067
# Iteration 5, loss = 2.90900084
# Iteration 6, loss = 2.76334468
# Iteration 7, loss = 2.69217152
# Iteration 8, loss = 2.63585238
# Iteration 9, loss = 2.59784893
# Iteration 10, loss = 2.57963826
# Iteration 11, loss = 2.57348304
# Iteration 12, loss = 2.53058424
# Iteration 13, loss = 2.53753482
# Iteration 14, loss = 2.49890234
# Iteration 15, loss = 2.45810544
# Iteration 16, loss = 2.40293507
# Iteration 17, loss = 2.35559324
# Iteration 18, loss = 2.30037691
# Iteration 19, loss = 2.26228147
# Iteration 20, loss = 2.23832815
# Iteration 21, loss = 2.21255483
# Iteration 22, loss = 2.21953133
# Iteration 23, loss = 2.16353626
# Iteration 24, loss = 2.13724194
# Iteration 25, loss = 2.17559079
# Iteration 26, loss = 2.13270536
# Iteration 27, loss = 2.12212263
# Iteration 28, loss = 2.08688015
# Iteration 29, loss = 2.13828530
# Iteration 30, loss = 2.10247520
# Iteration 31, loss = 2.13830969
# Iteration 32, loss = 2.16545709
# Iteration 33, loss = 2.11018717
# Iteration 34, loss = 2.10888008
# Iteration 35, loss = 2.06295952
# Iteration 36, loss = 2.03545545
# Iteration 37, loss = 2.05141171
# Iteration 38, loss = 2.03116130
# Iteration 39, loss = 2.06441435
# Iteration 40, loss = 2.01110901
# Iteration 41, loss = 2.04197693
# Iteration 42, loss = 2.01854404
# Iteration 43, loss = 2.01835290
# Iteration 44, loss = 1.95208632
# Iteration 45, loss = 2.01817454
# Iteration 46, loss = 1.98113585
# Iteration 47, loss = 1.94909238
# Iteration 48, loss = 1.96360467
# Iteration 49, loss = 1.96689389
# Iteration 50, loss = 1.94006939
# Iteration 51, loss = 1.90400699
# Iteration 52, loss = 1.91447902
# Iteration 53, loss = 1.91403202
# Iteration 54, loss = 1.92975484
# Iteration 55, loss = 1.90329594
# Iteration 56, loss = 1.87530925
# Iteration 57, loss = 1.88059674
# Iteration 58, loss = 1.86109672
# Iteration 59, loss = 1.89793746
# Iteration 60, loss = 1.85700363
# Iteration 61, loss = 1.93204913
# Iteration 62, loss = 1.85869557
# Iteration 63, loss = 1.82261259
# Iteration 64, loss = 1.87059586
# Iteration 65, loss = 1.89702825
# Iteration 66, loss = 1.83135812
# Iteration 67, loss = 1.77627029
# Iteration 68, loss = 1.84485695
# Iteration 69, loss = 1.74531046
# Iteration 70, loss = 1.76686652
# Iteration 71, loss = 1.76939736
# Iteration 72, loss = 1.74477044
# Iteration 73, loss = 1.73167902
# Iteration 74, loss = 1.72775544
# Iteration 75, loss = 1.75809398
# Iteration 76, loss = 1.74350835
# Iteration 77, loss = 1.73379633
# Iteration 78, loss = 1.72819613
# Iteration 79, loss = 1.74482526
# Iteration 80, loss = 1.73298131
# Iteration 81, loss = 1.74017702
# Iteration 82, loss = 1.68620464
# Iteration 83, loss = 1.66993442
# Iteration 84, loss = 1.69869340
# Iteration 85, loss = 1.70201303
# Iteration 86, loss = 1.71613148
# Iteration 87, loss = 1.66802038
# Iteration 88, loss = 1.65091163
# Iteration 89, loss = 1.68604733
# Iteration 90, loss = 1.64311904
# Iteration 91, loss = 1.65999938
# Iteration 92, loss = 1.61542300
# Iteration 93, loss = 1.63763197
# Iteration 94, loss = 1.62258549
# Iteration 95, loss = 1.61848025
# Iteration 96, loss = 1.69164603
# Iteration 97, loss = 1.63524454
# Iteration 98, loss = 1.62252109
# Iteration 99, loss = 1.66292636
# Iteration 100, loss = 1.61452535
# Iteration 101, loss = 1.61325791
# Iteration 102, loss = 1.61358532
# Iteration 103, loss = 1.57875785
# Iteration 104, loss = 1.61136525
# Iteration 105, loss = 1.59412458
# Iteration 106, loss = 1.57034843
# Iteration 107, loss = 1.65849214
# Iteration 108, loss = 1.60257554
# Iteration 109, loss = 1.57720429
# Iteration 110, loss = 1.53767783
# Iteration 111, loss = 1.55519820
# Iteration 112, loss = 1.55778335
# Iteration 113, loss = 1.57084633
# Iteration 114, loss = 1.57475075
# Iteration 115, loss = 1.53828410
# Iteration 116, loss = 1.55871780
# Iteration 117, loss = 1.67919519
# Iteration 118, loss = 1.63038820
# Iteration 119, loss = 1.56529078
# Iteration 120, loss = 1.51736266
# Iteration 121, loss = 1.53612177
# Iteration 122, loss = 1.55174057
# Iteration 123, loss = 1.54025462
# Iteration 124, loss = 1.50277833
# Iteration 125, loss = 1.51685471
# Iteration 126, loss = 1.60258773
# Iteration 127, loss = 1.48652490
# Iteration 128, loss = 1.47940413
# Iteration 129, loss = 1.47731216
# Iteration 130, loss = 1.48915025
# Iteration 131, loss = 1.50228842
# Iteration 132, loss = 1.53254148
# Iteration 133, loss = 1.51255998
# Iteration 134, loss = 1.49298349
# Iteration 135, loss = 1.44024345
# Iteration 136, loss = 1.45952228
# Iteration 137, loss = 1.43352399
# Iteration 138, loss = 1.48855211
# Iteration 139, loss = 1.52905270
# Iteration 140, loss = 1.53225511
# Iteration 141, loss = 1.49981008
# Iteration 142, loss = 1.46936912
# Iteration 143, loss = 1.56101169
# Iteration 144, loss = 1.73139417
# Iteration 145, loss = 1.64759059
# Iteration 146, loss = 1.67064561
# Iteration 147, loss = 1.49025481
# Iteration 148, loss = 1.49387250
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 99.95303583145142
# Accuracy on valid set with a cepstral coef of  6: 50.4%
# Time to output features: 73.42301559448242
# Iteration 1, loss = 6.85246915
# Iteration 2, loss = 3.33823533
# Iteration 3, loss = 3.22261959
# Iteration 4, loss = 3.01736938
# Iteration 5, loss = 2.81871936
# Iteration 6, loss = 2.67034323
# Iteration 7, loss = 2.62492077
# Iteration 8, loss = 2.57951634
# Iteration 9, loss = 2.54791316
# Iteration 10, loss = 2.53582371
# Iteration 11, loss = 2.51177895
# Iteration 12, loss = 2.51089290
# Iteration 13, loss = 2.52169928
# Iteration 14, loss = 2.48730977
# Iteration 15, loss = 2.45429539
# Iteration 16, loss = 2.45969698
# Iteration 17, loss = 2.44995597
# Iteration 18, loss = 2.41522911
# Iteration 19, loss = 2.38705792
# Iteration 20, loss = 2.35820559
# Iteration 21, loss = 2.30978557
# Iteration 22, loss = 2.27954158
# Iteration 23, loss = 2.25338909
# Iteration 24, loss = 2.25430565
# Iteration 25, loss = 2.23326281
# Iteration 26, loss = 2.25722902
# Iteration 27, loss = 2.23461923
# Iteration 28, loss = 2.17704297
# Iteration 29, loss = 2.20087107
# Iteration 30, loss = 2.21993476
# Iteration 31, loss = 2.11831611
# Iteration 32, loss = 2.09375328
# Iteration 33, loss = 2.05059988
# Iteration 34, loss = 2.07931363
# Iteration 35, loss = 2.00618398
# Iteration 36, loss = 1.94611722
# Iteration 37, loss = 1.99450728
# Iteration 38, loss = 1.94603895
# Iteration 39, loss = 1.93416577
# Iteration 40, loss = 1.91813193
# Iteration 41, loss = 1.93327674
# Iteration 42, loss = 1.88054778
# Iteration 43, loss = 1.83299133
# Iteration 44, loss = 1.81927870
# Iteration 45, loss = 1.82280716
# Iteration 46, loss = 1.81642975
# Iteration 47, loss = 1.81102643
# Iteration 48, loss = 1.77713985
# Iteration 49, loss = 1.79298411
# Iteration 50, loss = 1.79276459
# Iteration 51, loss = 1.78309486
# Iteration 52, loss = 1.76002583
# Iteration 53, loss = 1.73348345
# Iteration 54, loss = 1.72148378
# Iteration 55, loss = 1.73969201
# Iteration 56, loss = 1.77442061
# Iteration 57, loss = 1.71201311
# Iteration 58, loss = 1.75183667
# Iteration 59, loss = 1.70430451
# Iteration 60, loss = 1.69598532
# Iteration 61, loss = 1.77155411
# Iteration 62, loss = 1.75659769
# Iteration 63, loss = 1.69472816
# Iteration 64, loss = 1.75290385
# Iteration 65, loss = 1.72801476
# Iteration 66, loss = 1.70845692
# Iteration 67, loss = 1.72887418
# Iteration 68, loss = 1.76261987
# Iteration 69, loss = 1.67851592
# Iteration 70, loss = 1.67824581
# Iteration 71, loss = 1.75189218
# Iteration 72, loss = 1.66759806
# Iteration 73, loss = 1.67722863
# Iteration 74, loss = 1.65541465
# Iteration 75, loss = 1.61880561
# Iteration 76, loss = 1.66233733
# Iteration 77, loss = 1.64748827
# Iteration 78, loss = 1.65807809
# Iteration 79, loss = 1.63661516
# Iteration 80, loss = 1.62759813
# Iteration 81, loss = 1.65160401
# Iteration 82, loss = 1.58906091
# Iteration 83, loss = 1.57738864
# Iteration 84, loss = 1.61816514
# Iteration 85, loss = 1.59182887
# Iteration 86, loss = 1.66347435
# Iteration 87, loss = 1.55046803
# Iteration 88, loss = 1.57227158
# Iteration 89, loss = 1.65941646
# Iteration 90, loss = 1.63435019
# Iteration 91, loss = 1.59151102
# Iteration 92, loss = 1.60899064
# Iteration 93, loss = 1.61034045
# Iteration 94, loss = 1.57902512
# Iteration 95, loss = 1.54052571
# Iteration 96, loss = 1.58200102
# Iteration 97, loss = 1.60344528
# Iteration 98, loss = 1.54834095
# Iteration 99, loss = 1.55464344
# Iteration 100, loss = 1.56343089
# Iteration 101, loss = 1.58037898
# Iteration 102, loss = 1.54878326
# Iteration 103, loss = 1.53583150
# Iteration 104, loss = 1.60138837
# Iteration 105, loss = 1.57309197
# Iteration 106, loss = 1.54885395
# Iteration 107, loss = 1.52395346
# Iteration 108, loss = 1.49717768
# Iteration 109, loss = 1.53163211
# Iteration 110, loss = 1.57037999
# Iteration 111, loss = 1.53808937
# Iteration 112, loss = 1.58379597
# Iteration 113, loss = 1.51530480
# Iteration 114, loss = 1.56895675
# Iteration 115, loss = 1.57069786
# Iteration 116, loss = 1.58180496
# Iteration 117, loss = 1.59329866
# Iteration 118, loss = 1.51593010
# Iteration 119, loss = 1.54440451
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 79.86973524093628
# Accuracy on valid set with a cepstral coef of  8: 54.300000000000004%
# Time to output features: 74.34618091583252
# Iteration 1, loss = 5.53439196
# Iteration 2, loss = 3.34186797
# Iteration 3, loss = 3.30884245
# Iteration 4, loss = 3.24051979
# Iteration 5, loss = 3.21023225
# Iteration 6, loss = 3.21421631
# Iteration 7, loss = 3.18064369
# Iteration 8, loss = 3.13858659
# Iteration 9, loss = 2.97478837
# Iteration 10, loss = 2.76242395
# Iteration 11, loss = 2.69238771
# Iteration 12, loss = 2.61104720
# Iteration 13, loss = 2.57080037
# Iteration 14, loss = 2.53716749
# Iteration 15, loss = 2.54711176
# Iteration 16, loss = 2.53614654
# Iteration 17, loss = 2.52727701
# Iteration 18, loss = 2.49859196
# Iteration 19, loss = 2.49221343
# Iteration 20, loss = 2.49304336
# Iteration 21, loss = 2.46743570
# Iteration 22, loss = 2.51481849
# Iteration 23, loss = 2.48515629
# Iteration 24, loss = 2.45582730
# Iteration 25, loss = 2.47902843
# Iteration 26, loss = 2.45329667
# Iteration 27, loss = 2.45328819
# Iteration 28, loss = 2.47764609
# Iteration 29, loss = 2.46977544
# Iteration 30, loss = 2.45125172
# Iteration 31, loss = 2.43947016
# Iteration 32, loss = 2.46530991
# Iteration 33, loss = 2.52921313
# Iteration 34, loss = 2.58007850
# Iteration 35, loss = 2.47065010
# Iteration 36, loss = 2.43585722
# Iteration 37, loss = 2.44813785
# Iteration 38, loss = 2.43244215
# Iteration 39, loss = 2.42183563
# Iteration 40, loss = 2.41496349
# Iteration 41, loss = 2.39098369
# Iteration 42, loss = 2.38026527
# Iteration 43, loss = 2.39245135
# Iteration 44, loss = 2.36994338
# Iteration 45, loss = 2.36370493
# Iteration 46, loss = 2.35680408
# Iteration 47, loss = 2.36201190
# Iteration 48, loss = 2.32499103
# Iteration 49, loss = 2.34492648
# Iteration 50, loss = 2.36297025
# Iteration 51, loss = 2.33483988
# Iteration 52, loss = 2.31609086
# Iteration 53, loss = 2.33452192
# Iteration 54, loss = 2.34436433
# Iteration 55, loss = 2.31125487
# Iteration 56, loss = 2.29280534
# Iteration 57, loss = 2.29776907
# Iteration 58, loss = 2.30012308
# Iteration 59, loss = 2.33497791
# Iteration 60, loss = 2.27122943
# Iteration 61, loss = 2.29498116
# Iteration 62, loss = 2.28448729
# Iteration 63, loss = 2.23005539
# Iteration 64, loss = 2.26858378
# Iteration 65, loss = 2.23811070
# Iteration 66, loss = 2.21842884
# Iteration 67, loss = 2.24154715
# Iteration 68, loss = 2.22412633
# Iteration 69, loss = 2.19656143
# Iteration 70, loss = 2.17166450
# Iteration 71, loss = 2.21992665
# Iteration 72, loss = 2.21127923
# Iteration 73, loss = 2.21802088
# Iteration 74, loss = 2.17829059
# Iteration 75, loss = 2.17417247
# Iteration 76, loss = 2.22793418
# Iteration 77, loss = 2.16876807
# Iteration 78, loss = 2.16394268
# Iteration 79, loss = 2.16420048
# Iteration 80, loss = 2.19639539
# Iteration 81, loss = 2.15967930
# Iteration 82, loss = 2.14258197
# Iteration 83, loss = 2.16337437
# Iteration 84, loss = 2.18050418
# Iteration 85, loss = 2.20055746
# Iteration 86, loss = 2.30186944
# Iteration 87, loss = 2.25525255
# Iteration 88, loss = 2.32068506
# Iteration 89, loss = 2.26851119
# Iteration 90, loss = 2.14807777
# Iteration 91, loss = 2.13832545
# Iteration 92, loss = 2.23228227
# Iteration 93, loss = 2.16710550
# Iteration 94, loss = 2.12406953
# Iteration 95, loss = 2.14194432
# Iteration 96, loss = 2.16471868
# Iteration 97, loss = 2.13800635
# Iteration 98, loss = 2.16811028
# Iteration 99, loss = 2.11989918
# Iteration 100, loss = 2.12403620
# Iteration 101, loss = 2.11070332
# Iteration 102, loss = 2.16449757
# Iteration 103, loss = 2.18269278
# Iteration 104, loss = 2.14089525
# Iteration 105, loss = 2.09819874
# Iteration 106, loss = 2.13329535
# Iteration 107, loss = 2.09717241
# Iteration 108, loss = 2.10788554
# Iteration 109, loss = 2.07500287
# Iteration 110, loss = 2.11694784
# Iteration 111, loss = 2.10926550
# Iteration 112, loss = 2.08345232
# Iteration 113, loss = 2.09922627
# Iteration 114, loss = 2.06705293
# Iteration 115, loss = 2.07063074
# Iteration 116, loss = 2.06787269
# Iteration 117, loss = 2.04773265
# Iteration 118, loss = 2.05056411
# Iteration 119, loss = 2.03059175
# Iteration 120, loss = 2.10303009
# Iteration 121, loss = 2.04687258
# Iteration 122, loss = 2.02816511
# Iteration 123, loss = 2.03874910
# Iteration 124, loss = 2.02372966
# Iteration 125, loss = 2.05755769
# Iteration 126, loss = 2.01345081
# Iteration 127, loss = 2.01654755
# Iteration 128, loss = 2.03016898
# Iteration 129, loss = 2.01237581
# Iteration 130, loss = 2.01955101
# Iteration 131, loss = 2.00542473
# Iteration 132, loss = 1.97970652
# Iteration 133, loss = 2.08125626
# Iteration 134, loss = 1.99214896
# Iteration 135, loss = 2.00010308
# Iteration 136, loss = 2.00605614
# Iteration 137, loss = 2.04858993
# Iteration 138, loss = 2.01065185
# Iteration 139, loss = 2.01469484
# Iteration 140, loss = 2.00786216
# Iteration 141, loss = 1.97496856
# Iteration 142, loss = 1.97900982
# Iteration 143, loss = 1.95661169
# Iteration 144, loss = 1.96928757
# Iteration 145, loss = 2.01213641
# Iteration 146, loss = 2.00395817
# Iteration 147, loss = 1.94910776
# Iteration 148, loss = 1.99663487
# Iteration 149, loss = 2.00904554
# Iteration 150, loss = 2.02093827
# Iteration 151, loss = 1.98981140
# Iteration 152, loss = 2.03348674
# Iteration 153, loss = 1.97009201
# Iteration 154, loss = 1.98583391
# Iteration 155, loss = 1.96443662
# Iteration 156, loss = 2.00486671
# Iteration 157, loss = 1.97067410
# Iteration 158, loss = 1.95456618
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 146.39556336402893
# Accuracy on valid set with a cepstral coef of  12: 30.7%
# Time to output features: 74.188143491745
# Iteration 1, loss = 5.71619870
# Iteration 2, loss = 3.36102862
# Iteration 3, loss = 3.29702423
# Iteration 4, loss = 3.22404462
# Iteration 5, loss = 3.09113124
# Iteration 6, loss = 2.99374609
# Iteration 7, loss = 2.95212499
# Iteration 8, loss = 2.92597353
# Iteration 9, loss = 2.90068798
# Iteration 10, loss = 2.88134234
# Iteration 11, loss = 2.88691307
# Iteration 12, loss = 2.88859382
# Iteration 13, loss = 2.86435504
# Iteration 14, loss = 2.82569360
# Iteration 15, loss = 2.79144706
# Iteration 16, loss = 2.73561316
# Iteration 17, loss = 2.67879559
# Iteration 18, loss = 2.64998875
# Iteration 19, loss = 2.56180926
# Iteration 20, loss = 2.49391159
# Iteration 21, loss = 2.51693190
# Iteration 22, loss = 2.45517051
# Iteration 23, loss = 2.39971389
# Iteration 24, loss = 2.39713549
# Iteration 25, loss = 2.43543126
# Iteration 26, loss = 2.41906716
# Iteration 27, loss = 2.35936667
# Iteration 28, loss = 2.33240716
# Iteration 29, loss = 2.30872013
# Iteration 30, loss = 2.32572401
# Iteration 31, loss = 2.31847506
# Iteration 32, loss = 2.27328204
# Iteration 33, loss = 2.29502999
# Iteration 34, loss = 2.26984970
# Iteration 35, loss = 2.26773332
# Iteration 36, loss = 2.31505152
# Iteration 37, loss = 2.22545278
# Iteration 38, loss = 2.21979888
# Iteration 39, loss = 2.20452081
# Iteration 40, loss = 2.19117213
# Iteration 41, loss = 2.21688139
# Iteration 42, loss = 2.20757218
# Iteration 43, loss = 2.23424597
# Iteration 44, loss = 2.27060563
# Iteration 45, loss = 2.27446601
# Iteration 46, loss = 2.17402311
# Iteration 47, loss = 2.25088825
# Iteration 48, loss = 2.20571541
# Iteration 49, loss = 2.17911978
# Iteration 50, loss = 2.20474088
# Iteration 51, loss = 2.13661519
# Iteration 52, loss = 2.16363531
# Iteration 53, loss = 2.15022742
# Iteration 54, loss = 2.10278963
# Iteration 55, loss = 2.15035143
# Iteration 56, loss = 2.09491650
# Iteration 57, loss = 2.07142697
# Iteration 58, loss = 2.05280233
# Iteration 59, loss = 2.03561283
# Iteration 60, loss = 2.03490290
# Iteration 61, loss = 2.03015472
# Iteration 62, loss = 2.04488421
# Iteration 63, loss = 2.00628242
# Iteration 64, loss = 2.03554354
# Iteration 65, loss = 1.98427481
# Iteration 66, loss = 1.94360197
# Iteration 67, loss = 1.95323079
# Iteration 68, loss = 1.98372278
# Iteration 69, loss = 1.92239551
# Iteration 70, loss = 1.92691714
# Iteration 71, loss = 1.95744928
# Iteration 72, loss = 1.94400809
# Iteration 73, loss = 1.92810727
# Iteration 74, loss = 1.94905749
# Iteration 75, loss = 1.92026677
# Iteration 76, loss = 1.89880022
# Iteration 77, loss = 1.89431377
# Iteration 78, loss = 1.85724037
# Iteration 79, loss = 1.90816240
# Iteration 80, loss = 1.86153174
# Iteration 81, loss = 1.86462266
# Iteration 82, loss = 1.89901441
# Iteration 83, loss = 1.86336646
# Iteration 84, loss = 1.91574990
# Iteration 85, loss = 1.92261873
# Iteration 86, loss = 1.90414652
# Iteration 87, loss = 1.93179755
# Iteration 88, loss = 1.87055874
# Iteration 89, loss = 1.83919295
# Iteration 90, loss = 1.87448116
# Iteration 91, loss = 1.84480700
# Iteration 92, loss = 1.83943810
# Iteration 93, loss = 1.88169169
# Iteration 94, loss = 1.83721666
# Iteration 95, loss = 1.88723435
# Iteration 96, loss = 1.82275765
# Iteration 97, loss = 1.77457172
# Iteration 98, loss = 1.78894369
# Iteration 99, loss = 1.78469203
# Iteration 100, loss = 1.79596064
# Iteration 101, loss = 1.88069691
# Iteration 102, loss = 1.91519127
# Iteration 103, loss = inf
# Iteration 104, loss = 1.97713597
# Iteration 105, loss = 1.87127087
# Iteration 106, loss = 1.78267210
# Iteration 107, loss = 1.73276076
# Iteration 108, loss = 1.79133357
# Iteration 109, loss = 1.75594989
# Iteration 110, loss = 1.75499243
# Iteration 111, loss = 1.75461552
# Iteration 112, loss = 1.75821670
# Iteration 113, loss = 1.71268242
# Iteration 114, loss = 1.68184106
# Iteration 115, loss = 1.66843645
# Iteration 116, loss = 1.70121445
# Iteration 117, loss = 1.65043775
# Iteration 118, loss = 1.66395773
# Iteration 119, loss = 1.64737033
# Iteration 120, loss = 1.64659901
# Iteration 121, loss = 1.65724101
# Iteration 122, loss = 1.63360766
# Iteration 123, loss = 1.65554682
# Iteration 124, loss = 1.70119939
# Iteration 125, loss = 1.66648277
# Iteration 126, loss = 1.68058581
# Iteration 127, loss = 1.61162437
# Iteration 128, loss = 1.62763847
# Iteration 129, loss = 1.62823207
# Iteration 130, loss = 1.70514173
# Iteration 131, loss = 1.62145428
# Iteration 132, loss = 1.66584477
# Iteration 133, loss = 1.60173469
# Iteration 134, loss = 1.59452692
# Iteration 135, loss = 1.62655628
# Iteration 136, loss = 1.57391758
# Iteration 137, loss = 1.61572973
# Iteration 138, loss = 1.61001147
# Iteration 139, loss = 1.60712404
# Iteration 140, loss = 1.59784205
# Iteration 141, loss = 1.61031667
# Iteration 142, loss = 1.53763307
# Iteration 143, loss = 1.61824942
# Iteration 144, loss = 1.64812939
# Iteration 145, loss = 1.59569405
# Iteration 146, loss = 1.60977462
# Iteration 147, loss = 1.55136329
# Iteration 148, loss = 1.53671390
# Iteration 149, loss = 1.60466774
# Iteration 150, loss = 1.57192345
# Iteration 151, loss = 1.53625742
# Iteration 152, loss = 1.63143323
# Iteration 153, loss = 1.56339892
# Iteration 154, loss = 1.55114063
# Iteration 155, loss = 1.51199200
# Iteration 156, loss = 1.53118298
# Iteration 157, loss = 1.59811444
# Iteration 158, loss = 1.57479766
# Iteration 159, loss = 1.56478439
# Iteration 160, loss = 1.52954965
# Iteration 161, loss = 1.52381983
# Iteration 162, loss = 1.54104132
# Iteration 163, loss = 1.59735724
# Iteration 164, loss = 1.53661879
# Iteration 165, loss = 1.59911947
# Iteration 166, loss = 1.52363394
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 208.56886053085327
# Accuracy on valid set with a cepstral coef of  16: 40.2%
# Time to output features: 74.72706484794617
# Iteration 1, loss = 6.43379641
# Iteration 2, loss = 3.42118682
# Iteration 3, loss = 3.39852237
# Iteration 4, loss = 3.30655392
# Iteration 5, loss = 3.23026393
# Iteration 6, loss = 3.15764241
# Iteration 7, loss = 3.15947133
# Iteration 8, loss = 3.10686036
# Iteration 9, loss = 2.96969920
# Iteration 10, loss = 2.88234133
# Iteration 11, loss = 2.83961827
# Iteration 12, loss = 2.87488371
# Iteration 13, loss = 2.79635130
# Iteration 14, loss = 2.69866702
# Iteration 15, loss = 2.64120824
# Iteration 16, loss = 2.61215912
# Iteration 17, loss = 2.59596313
# Iteration 18, loss = 2.56207166
# Iteration 19, loss = 2.56702465
# Iteration 20, loss = 2.54166897
# Iteration 21, loss = 2.53785963
# Iteration 22, loss = 2.47711952
# Iteration 23, loss = 2.45481351
# Iteration 24, loss = 2.42822657
# Iteration 25, loss = 2.43048499
# Iteration 26, loss = 2.41134093
# Iteration 27, loss = 2.46928699
# Iteration 28, loss = 2.46757807
# Iteration 29, loss = 2.43786442
# Iteration 30, loss = 2.35312755
# Iteration 31, loss = 2.38259428
# Iteration 32, loss = 2.37256951
# Iteration 33, loss = 2.32411312
# Iteration 34, loss = 2.30771649
# Iteration 35, loss = 2.32994174
# Iteration 36, loss = 2.29215814
# Iteration 37, loss = 2.27193292
# Iteration 38, loss = 2.24961413
# Iteration 39, loss = 2.22587027
# Iteration 40, loss = 2.24550462
# Iteration 41, loss = 2.23513230
# Iteration 42, loss = 2.19979620
# Iteration 43, loss = 2.18859625
# Iteration 44, loss = 2.17891124
# Iteration 45, loss = 2.15404561
# Iteration 46, loss = 2.10878165
# Iteration 47, loss = 2.12395539
# Iteration 48, loss = 2.09678314
# Iteration 49, loss = 2.10534608
# Iteration 50, loss = 2.06917953
# Iteration 51, loss = 2.07844339
# Iteration 52, loss = 2.01731378
# Iteration 53, loss = 2.06028450
# Iteration 54, loss = 2.01788003
# Iteration 55, loss = 2.07426549
# Iteration 56, loss = 2.04412962
# Iteration 57, loss = 2.03174078
# Iteration 58, loss = 2.05277075
# Iteration 59, loss = 2.03970732
# Iteration 60, loss = 1.97202652
# Iteration 61, loss = 1.97490484
# Iteration 62, loss = 2.02722354
# Iteration 63, loss = 1.98730792
# Iteration 64, loss = 1.95636031
# Iteration 65, loss = 1.94961959
# Iteration 66, loss = 2.00704297
# Iteration 67, loss = 2.06240994
# Iteration 68, loss = 1.96171787
# Iteration 69, loss = 1.95328926
# Iteration 70, loss = 2.00061845
# Iteration 71, loss = 1.98061388
# Iteration 72, loss = 1.94184099
# Iteration 73, loss = 1.94176873
# Iteration 74, loss = 1.93267466
# Iteration 75, loss = 1.92805372
# Iteration 76, loss = 1.91255230
# Iteration 77, loss = 1.86919206
# Iteration 78, loss = 1.85755739
# Iteration 79, loss = 1.83986454
# Iteration 80, loss = 1.82749162
# Iteration 81, loss = 1.88597897
# Iteration 82, loss = 1.86348522
# Iteration 83, loss = 1.84710212
# Iteration 84, loss = 1.83007312
# Iteration 85, loss = 1.91112980
# Iteration 86, loss = 1.87910978
# Iteration 87, loss = 1.79975377
# Iteration 88, loss = 1.79174857
# Iteration 89, loss = 1.82421719
# Iteration 90, loss = 1.82933140
# Iteration 91, loss = 1.78612851
# Iteration 92, loss = 1.77616674
# Iteration 93, loss = 1.83928563
# Iteration 94, loss = 1.85630281
# Iteration 95, loss = 1.84224324
# Iteration 96, loss = 1.78447648
# Iteration 97, loss = 1.83658692
# Iteration 98, loss = 1.83135265
# Iteration 99, loss = 1.86390504
# Iteration 100, loss = 1.80775256
# Iteration 101, loss = 1.83447304
# Iteration 102, loss = 1.77471378
# Iteration 103, loss = 1.79215082
# Iteration 104, loss = 1.75204789
# Iteration 105, loss = 1.77053628
# Iteration 106, loss = 1.81072272
# Iteration 107, loss = 1.74744252
# Iteration 108, loss = 1.76054885
# Iteration 109, loss = 1.74858339
# Iteration 110, loss = 1.75765187
# Iteration 111, loss = 1.85280054
# Iteration 112, loss = 1.80860942
# Iteration 113, loss = 1.78399348
# Iteration 114, loss = 1.76648437
# Iteration 115, loss = 1.78030816
# Iteration 116, loss = 1.74931402
# Iteration 117, loss = 1.68786337
# Iteration 118, loss = 1.75337258
# Iteration 119, loss = 1.71919962
# Iteration 120, loss = 1.74924159
# Iteration 121, loss = 1.69105296
# Iteration 122, loss = 1.72435186
# Iteration 123, loss = 1.74280403
# Iteration 124, loss = 1.73346893
# Iteration 125, loss = 1.68580180
# Iteration 126, loss = 1.69758256
# Iteration 127, loss = 1.72550447
# Iteration 128, loss = 1.70769479
# Iteration 129, loss = 1.65313803
# Iteration 130, loss = 1.69194321
# Iteration 131, loss = 1.68075345
# Iteration 132, loss = 1.65872043
# Iteration 133, loss = 1.72601763
# Iteration 134, loss = 1.67502439
# Iteration 135, loss = 1.72028265
# Iteration 136, loss = 1.65456503
# Iteration 137, loss = 1.64927834
# Iteration 138, loss = 1.63764564
# Iteration 139, loss = 1.62787841
# Iteration 140, loss = 1.69903133
# Iteration 141, loss = 1.62934772
# Iteration 142, loss = 1.63409193
# Iteration 143, loss = 1.60932885
# Iteration 144, loss = 1.66815747
# Iteration 145, loss = 1.63525316
# Iteration 146, loss = 1.60476660
# Iteration 147, loss = 1.61212332
# Iteration 148, loss = 1.58325119
# Iteration 149, loss = 1.60802693
# Iteration 150, loss = 1.63467629
# Iteration 151, loss = 1.72362866
# Iteration 152, loss = 1.64810330
# Iteration 153, loss = 1.69434527
# Iteration 154, loss = 1.66970224
# Iteration 155, loss = 1.68091570
# Iteration 156, loss = 1.66525478
# Iteration 157, loss = 1.64085238
# Iteration 158, loss = 1.62168789
# Iteration 159, loss = 1.64074858
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Training time: 289.0286476612091
# Accuracy on valid set with a cepstral coef of  24: 40.699999999999996%

# %% [markdown]
# **Question 1.3**

# %%
deltas =[True,False]
deltasdeltas=[True,False]
fig, ax = plt.subplots(figsize=(15, 10))
i=0
for delta in deltas :
  for deltasdelta in deltasdeltas :
    mfcc = spectral.Spectral(nfilt=40,
                        ncep=12,
                        do_dct=True,
                        lowerf=300,
                        upperf=6000,
                        alpha=0.6,
                        fs=framerate,
                        frate=100,
                        wlen=0.035,
                        nfft=500,
                        compression='log',
                        do_deltas=delta,
                        do_deltasdeltas=deltasdelta)
    # Choose the feature function
    feature_function = mfcc

    start = time.time()
    train_feats = np.asarray(pad(transform_wavs(train_wavs, feature_function)))
    valid_feats = np.asarray(pad(transform_wavs(valid_wavs, feature_function)))
    test_feats = np.asarray(pad(transform_wavs(test_wavs, feature_function)))
    end = time.time()
    print ( '1st derivatives: '+str(do_deltas)+', 2nd derivatives: '+str(do_deltasdeltas))
    print("Time to output features: " + str(end-start))
    neural_net = MLPClassifier(hidden_layer_sizes=(100,), validation_fraction = 0.2, early_stopping = False,
                                      verbose = True, random_state = 777, learning_rate='constant',
                                      learning_rate_init=0.01)

    start = time.time()
    neural_net.fit(train_feats, train_labels)
    end = time.time()

    print("Training time (""): " + str(end-start))
    ax.plot(neural_net.loss_curve_, label='1st derivatives: '+str(do_deltas)+', 2nd derivatives: '+str(do_deltasdeltas))
    i+=1
    print("Accuracy on valid set with  "'1st derivatives: '+str(do_deltas)+', 2nd derivatives: '+str(do_deltasdeltas) + str(100*neural_net.score(valid_feats, valid_labels)) + "%")
ax.legend()
ax.set_xlabel('Itertations')
ax.set_ylabel("Validation Loss")
plt.show()

# %% [markdown]
# **Question 1.4**

# %% [markdown]
# **Per-Channel Normalization**

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(train_feats)
train_feats_PC=scaler.transform(train_feats)
valid_feats_PC=scaler.transform(valid_feats)
test_feats_PC=scaler.transform(test_feats)

# %% [markdown]
# **Across Channel Normalization**

# %%
mean=train_feats.mean()
std=train_feats.std()
train_feats_AC=(train_feats-mean)/std 
valid_feats_AC=(valid_feats-mean)/std 
test_feats_AC=(test_feats-mean)/std

# %% [markdown]
# **Adding Noise**

# %%
def add_noise(noises,commands):
  noisy_dataset=[]
  for command in commands: 
    l=command.shape[0]
    noise=random.sample(noises,1)[0]
    start=random.randint(0,noise.shape[0]-l-1)
    noise_sample=noise[start:start+l]
    mean1=noise_sample.mean()
    while mean1==0 :
      start=random.randint(0,noise.shape[0]-l-1)
      noise_sample=noise[start:start+l]
      mean1=noise_sample.mean()
    mean2=command.mean()
    noisy_dataset+=[command+noise_sample*mean2/mean1]
  return noisy_dataset

noise_paths = glob.glob('./speech_commands/_background_noise_/*wav')
noises = []
for path in noise_paths:
    fs, waveform = wav.read(path)
    noises.append(waveform) 
train_wavs+=(add_noise(noises,train_wavs))
train_labels+=train_labels

# %% [markdown]
# ## II. Classification of segmented voice commands
#
# ### Prediction of Sequences
# In the second part of the practical work, you are now given a new dataset composed of commands from the same dataset as the first part. This dataset is still composed of audio signal, but of variable lengths.
#
# We denote by $X_{i=1...M}$  input sequence of spoken words, and the goal is to find the most likely sequence of words $W_{i=1...T}$.
#
#
# $ \operatorname*{argmax}_W P(W|X) \approx P(X|W) P(W)   $
#
#
# You saw in class that estimate $P(X|W)$ is the acoustic model part and $P(W)$ is the language model part.
#
# Solving this $argmax$ problem is a **search** problem.  It can be solved with dynamic programming with the [Viterbi algorithm](https://en.wikipedia.org/wiki/Viterbi_algorithm) or with heuristics such as [beam-search](https://en.wikipedia.org/wiki/Beam_search) techniques.
#
# Usually, we have $M>>T$, however in this case, to simplify the practical work, we have $M==T$, and use the posterior from your best classifier of the previous part.
#
# In our case , the acoustic model is taken from the discriminator trained in the first part. Therefore, we can model differently the acoustic model.
#
# $  P(X_i|W_i)  \propto P_{\text{discriminator single word}}(W_i|X_i)  $
#
# **Question 2.1**: Can you point which line in the code above approximated the prior probability of each word $W_i$ to be equal?
#
# ### Evalution with Word Error Rate
# To evaluate the performance of all your decoding strategies, we will use the **Word Error Rate**. It uses dynamic programming to align and compare the hypothesis and reference sequences. There are three type of errors under consideration: Insertion, Deletion and Substitution.
#
#  $WER = 100.\frac{S+D+I}{N}\%$
#
# - S is the total number of substitutions
# - D is the total number of deletions
# - I is the total number of insertions
# - N is the number of words in the reference sentence
#
# **Question 2.2**: Is it possible that WER<0? and WER>100?

# %%
# !wget https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/train_sequence_list.txt 
# !wget https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/test_sequence_list.txt 


path_to_wavs = '/content/speech_commands/'
train_sequence_list = [ast.literal_eval(ex) for ex in txt2list('/content/train_sequence_list.txt') ]
test_sequence_list = [ast.literal_eval(ex) for ex in txt2list('/content/test_sequence_list.txt') ]

def generate_wav_from_list_sequence(generated_list_sequence): 
    wavs = np.array([])
    for command in generated_list_sequence[1:]:
        wav_name = os.path.join((path_to_wavs),command[1])
        sample_rate, signal = wav.read(wav_name)
        wavs = np.append(wavs,signal)
    return wavs


# Again warning do not forget to change your pad function according to your choice of input features
  
def generate_posteriors_from_list_sequence(generated_list_sequence, model_predict_proba_function, feature_func): 
    posteriors = []
    for command in generated_list_sequence[1:]:
        wav_name = os.path.join((path_to_wavs),command[1])
        sample_rate, signal = wav.read(wav_name)
        features_input = np.asarray(pad(transform_wavs([signal], feature_function)))
        posterior = model_predict_proba_function(features_input)
        posteriors.append(posterior)
    
    posteriors = np.array(posteriors).reshape(-1,len(label_set))
    return posteriors

example_sequence = train_sequence_list[10]
sequence_wav  = generate_wav_from_list_sequence(example_sequence)

IPython.display.Audio(sequence_wav, rate=16000)
# Out:
# --2019-02-06 18:19:27--  https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/train_sequence_list.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1277360 (1.2M) [text/plain]
# Saving to: ‘train_sequence_list.txt.20’
#
# train_sequence_list 100%[===================>]   1.22M  3.35MB/s    in 0.4s
#
# 2019-02-06 18:19:28 (3.35 MB/s) - ‘train_sequence_list.txt.20’ saved [1277360/1277360]
#
# --2019-02-06 18:19:28--  https://raw.githubusercontent.com/Rachine/Rachine.github.io/master/data/test_sequence_list.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76236 (74K) [text/plain]
# Saving to: ‘test_sequence_list.txt.20’
#
# test_sequence_list. 100%[===================>]  74.45K  --.-KB/s    in 0.02s
#
# 2019-02-06 18:19:29 (3.02 MB/s) - ‘test_sequence_list.txt.20’ saved [76236/76236]
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### 1. Independent inputs
# #### Greedy search
#
# You will find below an implementation of a greedy decoder assuming full independance between spoken word commands without the alignement problem (each input is matched with one single output).
#
# We use a model from the previous part, **up to you** to use another one to improve the overall performance.

# %%
example_sequence = train_sequence_list[10]

posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(example_sequence, neural_net.predict_proba, mfcc))


list_plots = plt.plot(['Word_'+str(el) for el in range(posteriors_neural_mfcc.shape[0])],posteriors_neural_mfcc)
plt.legend(list_plots, label_set, loc="upper left", bbox_to_anchor=(1,1), ncol=6)
plt.ylabel('Posterior activations')
plt.title('Neural network activations with bad MFCCs')
plt.show()


def greedy_decoder(data):
  predicted_sequence = [np.argmax(s) for s in data]
  predicted_sequence = [label_set[el] for el in predicted_sequence]
  return predicted_sequence

def sequence_format_to_text(sentence):
  return [el[0] for el in sentence[1:]]

predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
print('True sentence: ', ' '.join(sequence_format_to_text(example_sequence)))
print('Predicted sentence with greedy search: ', ' '.join(predicted_sequence))
print('WER: ',jiwer.wer(' '.join(sequence_format_to_text(example_sequence)),' '.join(predicted_sequence)))
# Out:
# True sentence:  go marvin one right stop
# Predicted sentence with greedy search:  up marvin one on sheila
# WER:  0.6

# %% [markdown]
# **Question 2.3**: Can you detail the computations of the WER for the example above?

# %%
# Evaluation of WER for the Greedt Search decoding

train_hypothesis = []
train_reference = []

# EVALUATION on the full train set takes too much time, so you should evaluate on a subset

for sentence in  np.random.choice(train_sequence_list, 300, replace=False):
  posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, neural_net.predict_proba, mfcc))
  predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
  train_hypothesis.append(' '.join(predicted_sequence))
  train_reference.append(' '.join(sequence_format_to_text(sentence)))
  
  
test_hypothesis = []
test_reference = []
for idx, sentence in enumerate(test_sequence_list):
  posteriors_neural_mfcc = np.array(generate_posteriors_from_list_sequence(sentence, neural_net.predict_proba, mfcc))
  predicted_sequence = greedy_decoder(posteriors_neural_mfcc)
  test_hypothesis.append(' '.join(predicted_sequence))
  test_reference.append(' '.join(sequence_format_to_text(sentence)))

  
start = time.time()
print('Subset Train WER: ',jiwer.wer(train_reference, train_hypothesis))
print('Test WER: ',jiwer.wer(test_reference, test_hypothesis))

end = time.time()

print("Evaluation time: " + str(end-start))
# Out:
# Subset Train WER:  0.7991042866282789
# Test WER:  0.7852960312296682
# Evaluation time: 32.58004546165466

# %% [markdown]
# You will notice with greedy search and without language model, the train WER and test WER are approximately the same.

# %% [markdown]
# ### Inject Language Models in the path scoring
#
# Now, you will incorporate higher information, to improve on the simple classifier that you implemented above. You need to model the transition states $i\rightarrow j$.
#
# #### N-gram model
# You need to estimate and build now this transition matrix. You are only allowed to use the training sequence set to build the language model.
# You can refer to the class to have some ideas, or this paper:
#
# [The Application of Hidden Markov Models in Speech Recognition](https://s3.amazonaws.com/academia.edu.documents/40150101/The_Application_of_Hidden_Markov_Models_20151118-22759-1ab3mz1.pdf?AWSAccessKeyId=AKIAIWOWYYGZ2Y53UL3A&Expires=1549387878&Signature=Q%2FQiFLEgWJAvttO1LbP%2Fkb2OGaw%3D&response-content-disposition=inline%3B%20filename%3DThe_Application_of_Hidden_Markov_Models.pdf) part 2.4
#
# **Question 2.4**: Write the Bigram approximation formula of the language model
#
# **Question 2.5**: Explain briefly your implementation choices
#
# **Question 2.6**: What are the advantages and drawbacks to increase the N ?

# %%
# Build HERE the transition matrix with Bi-gram modelling. You can also do an implementation with bigger N.

# %% [markdown]
# ## Beam-Search
# Based on your transition matrix, your best discriminator, implement the Beam-Search algorithm.
#
# **Question 2.7**: What are the time and memory complexity of the Beam search algorithm?

# %%
# Beam-search decoder
# BELOW IMPLEMENT YOUR BEAM_SEARCH algorithm
def beam_search_decoder(data,transition_matrix, beam_size=5):
  raise('Not implemented')
  predicted_sequence = [np.argmax(s) for s in data]
  predicted_sequence = [label_set[el] for el in predicted_sequence]
  return predicted_sequence

# %% [markdown]
# ## Dynamic progamming with the Viterbi algorithm
# **Question 2.8**: What is the relationship between the probability to be in state  𝑗  at step  𝑘 , and the probabilities to be in state  𝑗′  at step  𝑘−1 ? What are the final time and memory complexity of the Viterbi algorithm?
#
# Based on your transition matrix, your best discriminator, implement now the Viterbi algorithm.

# %%
# Viterbi decoder
# BELOW IMPLEMENT YOUR viterbi algorithm

def viterbi_decoder(data,transition_matrix):
  raise('Not implemented')
  predicted_sequence = [np.argmax(s) for s in data]
  predicted_sequence = [label_set[el] for el in predicted_sequence]
  return predicted_sequence

# %% [markdown]
# # Results for decoding algorithms
#
# In your report for this practical work, you should examine your experiments: the different strategies with  the different implementation choices you made and the various parameters.
#
# **Question 2.9** Compare the performance of the Greedy, Beam-search and Viterbi algorithm: In theory which one is the best and why? What are the results in practice? Comment on the results
#
# **Question 2.10**: Can you spot systematic errors due to language model you derived from the training sequences? Provide us some of these errors.
#
# **Question 2.11**:  Can you implement some backoff strategies to face rare seen words(or sequence of words)?  Can you implement some backoff strategies to face Out of Vocabulary (OOV) words? Does it improve your Word Error Rate?
#
# **Question 2.12**:  How would you optimize jointly an acoustic model and language model?

# %% [markdown]
# # What you are expected to do in this second part
# The second part of the TP above contains the different blocks that allow you to decode sequence of speech commands. You are expected to implement the different decoding algorithms and compare them in WER performance, time and memory costs.
#  There are several question in this part, include your answers in the report. The **grade will not depend on the performance of the final system**, but on how you **experimented, tried different ideas, and comment** on them.

# %% [markdown]
# # Final Report and Notebook
# Write your report in a external PDF file, and send the **commented clean** ipython notebook along your assignment at mva.speech.language@gmail.com with title '[TP1_2020] FirstName_LastName'
#
#
# The report needs to be **succint**. It will include formula, results graphs, and your critical analysis of the experiments. All the questions **need to be answered in the pdf report**. Answers in the notebook will not be taken into account.
#
# Good luck!
#
#
# ---
